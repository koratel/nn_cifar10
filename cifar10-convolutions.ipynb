# %% [markdown]
# # CIFAR10 classification with convolutional neural network

# %% [markdown]
# Michał Łowicki, 258350

# %% [markdown]
# Code adapted from the [MNIST convolutions example](https://sites.google.com/a/cs.uni.wroc.pl/jch/teaching/neuralnetworks15/materialsforlectures710/10-convolutions.ipynb).

# %% [markdown]
# ###Test data accuracy: 82.24%

# %% [markdown]
# ### Architecture
#
# This neural network consists of the following layers:
#
# 1. Convolution with 50 5x5 filters
# 2. 2x2 maxpool
# 3. Convolution with 100 5x5 filters
# 4. 2x2 maxpool
# 5. Fully connected with 500 neurons
# 6. ReLU
# 7. Fully connected with 500 neurons
# 8. ReLU
# 9. Fully connected with 100 neurons
# 10. ReLU
# 11. Fully connected with 10 neurons
# 12. SoftMax

# %% [markdown]
# ### Main improvement - generating synthetic data
#
# To lower variance the training input is "shaken" - each picture from the batch is randomly rolled by -4 to 4 pixels up and down independently (elements that roll beyond the last position are re-introduced at the beginning). This artificially increases the training set size 81 times and decreases the network's ability to over-fit - it can no longer easily achieve >99% accuracy on training data. In result the test data accuracy significantly improved from 75.43% to 82.24%.
#
# The downside is increased training time (over 100 epochs are needed), but the improvement in accuracy fully justifies that.

# %%
# %pylab inline

import theano
import theano.tensor.signal.downsample
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 21 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 21 days
# Using gpu device 0: GeForce GTX 780
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Data streams

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the CIFAR set and return us batches of 25 examples
cifar_train_stream = DataStream.default_stream(
    cifar_train,
    iteration_scheme=ShuffledScheme(cifar_train.num_examples, 25))
                                               
cifar_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar_validation_stream = DataStream.default_stream(
    cifar_validation, iteration_scheme=SequentialScheme(cifar_validation.num_examples, 100))
cifar_test = CIFAR10(("test",))
cifar_test_stream = DataStream.default_stream(
    cifar_test, iteration_scheme=SequentialScheme(cifar_test.num_examples, 100))

# %%
print "The streams return batches containing %s" % (cifar_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'raise' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 50 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'),
                   name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'),
                    name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x')
    )
# print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
# print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 100 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'),
                   name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'),
                    name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x')
    )
# print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
# print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=500
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'),
                   name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)

FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'),
                    name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
# print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)

num_fw3a_hidden=500
FW3a = theano.shared(np.zeros((num_fw3_hidden, num_fw3a_hidden), dtype='float32'),
                   name='FW3a')
FW3a.tag.initializer = IsotropicGaussian(0.05)

FB3a = theano.shared(np.zeros((num_fw3a_hidden,), dtype='float32'),
                    name='FB3a')
FB3a.tag.initializer = Constant(0.0)
model_parameters += [FW3a, FB3a]

after_F3a = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3, FW3a) + FB3a.dimshuffle('x',0))
# print "after_F3a shape: %s" % (after_F3a.tag.test_value.shape,)

num_fw3b_hidden=100
FW3b = theano.shared(np.zeros((num_fw3a_hidden, num_fw3b_hidden), dtype='float32'),
                   name='FW3b')
FW3b.tag.initializer = IsotropicGaussian(0.05)

FB3b = theano.shared(np.zeros((num_fw3b_hidden,), dtype='float32'),
                    name='FB3b')
FB3b.tag.initializer = Constant(0.0)
model_parameters += [FW3b, FB3b]

after_F3b = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3a, FW3b) + FB3b.dimshuffle('x',0))
# print "after_F3b shape: %s" % (after_F3b.tag.test_value.shape,)

num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw3b_hidden, num_fw4_hidden), dtype='float32'),
                   name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'),
                    name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F3b, FW4) + FB4.dimshuffle('x',0)
# print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 2e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)

# %%
#
# We have built a computation graph for computing the error_rate, predictions and cost
#
#svgdotprint(nll)

# %%
# The updates will update our shared values
updates = []

# %%
lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW3a, Elemwise{sub,no_inplace}.0),
#  (FW3a, Elemwise{add,no_inplace}.0),
#  (V_FB3a, Elemwise{sub,no_inplace}.0),
#  (FB3a, Elemwise{add,no_inplace}.0),
#  (V_FW3b, Elemwise{sub,no_inplace}.0),
#  (FW3b, Elemwise{add,no_inplace}.0),
#  (V_FB3b, Elemwise{sub,no_inplace}.0),
#  (FB3b, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

# %%
#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
def shake(X_batch):
    ret = X_batch
    for i in range(ret.shape[0]):
        ret[i] = roll(ret[i],randint(-4,5),axis=1)
        ret[i] = roll(ret[i],randint(-4,5),axis=2)
    return ret

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# %%
# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 5000
        lrate = 2e-2 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(shake(X_batch), Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 400 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 400, batch loss 6.609904, batch nll 2.046382, batch error rate 68.000000%
# At minibatch 800, batch loss 4.225773, batch nll 1.735499, batch error rate 76.000000%
# At minibatch 1200, batch loss 2.912693, batch nll 1.497794, batch error rate 56.000000%
# At minibatch 1600, batch loss 1.944979, batch nll 1.089293, batch error rate 32.000000%
# After epoch 1: valid_err_rate: 53.500000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 64.047500% averaged train nll: 1.737319 averaged train loss: 4.921050
# At minibatch 2000, batch loss 2.218864, batch nll 1.643698, batch error rate 56.000000%
# At minibatch 2400, batch loss 2.255216, batch nll 1.816976, batch error rate 68.000000%
# At minibatch 2800, batch loss 2.016189, batch nll 1.642127, batch error rate 68.000000%
# At minibatch 3200, batch loss 1.694515, batch nll 1.341044, batch error rate 48.000000%
# After epoch 2: valid_err_rate: 48.380000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 54.657500% averaged train nll: 1.509390 averaged train loss: 1.999030
# At minibatch 3600, batch loss 1.696497, batch nll 1.350594, batch error rate 52.000000%
# At minibatch 4000, batch loss 1.697444, batch nll 1.353014, batch error rate 52.000000%
# At minibatch 4400, batch loss 1.697286, batch nll 1.343687, batch error rate 40.000000%
# At minibatch 4800, batch loss 1.528237, batch nll 1.169216, batch error rate 56.000000%
# After epoch 3: valid_err_rate: 50.240000% currently going to do 4 epochs
# After epoch 3: averaged train_err_rate: 50.587500% averaged train nll: 1.417320 averaged train loss: 1.766939
# At minibatch 5200, batch loss 1.950585, batch nll 1.576770, batch error rate 48.000000%
# At minibatch 5600, batch loss 1.477152, batch nll 1.099622, batch error rate 40.000000%
# At minibatch 6000, batch loss 1.753549, batch nll 1.374648, batch error rate 56.000000%
# At minibatch 6400, batch loss 2.204005, batch nll 1.828922, batch error rate 68.000000%
# After epoch 4: valid_err_rate: 41.720000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 47.237500% averaged train nll: 1.330458 averaged train loss: 1.704671
# At minibatch 6800, batch loss 1.764146, batch nll 1.382014, batch error rate 40.000000%
# At minibatch 7200, batch loss 1.784868, batch nll 1.403305, batch error rate 52.000000%
# At minibatch 7600, batch loss 1.670618, batch nll 1.289243, batch error rate 44.000000%
# At minibatch 8000, batch loss 1.386740, batch nll 1.008127, batch error rate 40.000000%
# After epoch 5: valid_err_rate: 36.010000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 43.122500% averaged train nll: 1.220542 averaged train loss: 1.601498
# At minibatch 8400, batch loss 1.643343, batch nll 1.261288, batch error rate 40.000000%
# At minibatch 8800, batch loss 1.482151, batch nll 1.097654, batch error rate 32.000000%
# At minibatch 9200, batch loss 1.422711, batch nll 1.040701, batch error rate 40.000000%
# At minibatch 9600, batch loss 2.128339, batch nll 1.747635, batch error rate 56.000000%
# After epoch 6: valid_err_rate: 38.700000% currently going to do 8 epochs
# After epoch 6: averaged train_err_rate: 40.140000% averaged train nll: 1.143187 averaged train loss: 1.525183
# At minibatch 10000, batch loss 1.514724, batch nll 1.128018, batch error rate 32.000000%
# At minibatch 10400, batch loss 1.596598, batch nll 1.205694, batch error rate 40.000000%
# At minibatch 10800, batch loss 1.345907, batch nll 0.959140, batch error rate 32.000000%
# At minibatch 11200, batch loss 1.311990, batch nll 0.924053, batch error rate 32.000000%
# After epoch 7: valid_err_rate: 32.910000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 37.957500% averaged train nll: 1.079487 averaged train loss: 1.466962
# At minibatch 11600, batch loss 1.307152, batch nll 0.916631, batch error rate 36.000000%
# At minibatch 12000, batch loss 1.480695, batch nll 1.091011, batch error rate 48.000000%
# At minibatch 12400, batch loss 1.786743, batch nll 1.400502, batch error rate 40.000000%
# At minibatch 12800, batch loss 1.552427, batch nll 1.165287, batch error rate 52.000000%
# After epoch 8: valid_err_rate: 34.320000% currently going to do 11 epochs
# After epoch 8: averaged train_err_rate: 35.915000% averaged train nll: 1.023855 averaged train loss: 1.412124
# At minibatch 13200, batch loss 1.131814, batch nll 0.742742, batch error rate 20.000000%
# At minibatch 13600, batch loss 1.370063, batch nll 0.981694, batch error rate 28.000000%
# At minibatch 14000, batch loss 1.192452, batch nll 0.805014, batch error rate 28.000000%
# At minibatch 14400, batch loss 1.740867, batch nll 1.351886, batch error rate 40.000000%
# After epoch 9: valid_err_rate: 30.660000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 34.325000% averaged train nll: 0.977591 averaged train loss: 1.366456
# At minibatch 14800, batch loss 1.178746, batch nll 0.787362, batch error rate 32.000000%
# At minibatch 15200, batch loss 1.936785, batch nll 1.541874, batch error rate 56.000000%
# At minibatch 15600, batch loss 1.333719, batch nll 0.939708, batch error rate 32.000000%
# At minibatch 16000, batch loss 1.168899, batch nll 0.776121, batch error rate 20.000000%
# After epoch 10: valid_err_rate: 29.360000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 33.160000% averaged train nll: 0.944453 averaged train loss: 1.337531
# At minibatch 16400, batch loss 1.162596, batch nll 0.766762, batch error rate 16.000000%
# At minibatch 16800, batch loss 1.528414, batch nll 1.133021, batch error rate 40.000000%
# At minibatch 17200, batch loss 1.147654, batch nll 0.754692, batch error rate 16.000000%
# At minibatch 17600, batch loss 1.250990, batch nll 0.855761, batch error rate 36.000000%
# After epoch 11: valid_err_rate: 30.350000% currently going to do 16 epochs
# After epoch 11: averaged train_err_rate: 31.630000% averaged train nll: 0.903964 averaged train loss: 1.298994
# At minibatch 18000, batch loss 1.176140, batch nll 0.781529, batch error rate 24.000000%
# At minibatch 18400, batch loss 1.320217, batch nll 0.922434, batch error rate 28.000000%
# At minibatch 18800, batch loss 1.153610, batch nll 0.757758, batch error rate 24.000000%
# At minibatch 19200, batch loss 0.986159, batch nll 0.591528, batch error rate 12.000000%
# After epoch 12: valid_err_rate: 30.830000% currently going to do 16 epochs
# After epoch 12: averaged train_err_rate: 30.790000% averaged train nll: 0.880339 averaged train loss: 1.275852
# At minibatch 19600, batch loss 1.192761, batch nll 0.796407, batch error rate 32.000000%
# At minibatch 20000, batch loss 1.229938, batch nll 0.831217, batch error rate 32.000000%
# At minibatch 20400, batch loss 1.451015, batch nll 1.054713, batch error rate 36.000000%
# At minibatch 20800, batch loss 1.332495, batch nll 0.937810, batch error rate 32.000000%
# After epoch 13: valid_err_rate: 30.400000% currently going to do 16 epochs
# After epoch 13: averaged train_err_rate: 29.900000% averaged train nll: 0.857753 averaged train loss: 1.254582
# At minibatch 21200, batch loss 1.242467, batch nll 0.841283, batch error rate 40.000000%
# At minibatch 21600, batch loss 1.047307, batch nll 0.648313, batch error rate 24.000000%
# At minibatch 22000, batch loss 1.477398, batch nll 1.079736, batch error rate 48.000000%
# At minibatch 22400, batch loss 1.083610, batch nll 0.684369, batch error rate 24.000000%
# After epoch 14: valid_err_rate: 27.960000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 29.505000% averaged train nll: 0.837805 averaged train loss: 1.236433
# At minibatch 22800, batch loss 0.930183, batch nll 0.528669, batch error rate 12.000000%
# At minibatch 23200, batch loss 0.881432, batch nll 0.478809, batch error rate 20.000000%
# At minibatch 23600, batch loss 0.928973, batch nll 0.525670, batch error rate 12.000000%
# At minibatch 24000, batch loss 1.020237, batch nll 0.618424, batch error rate 24.000000%
# After epoch 15: valid_err_rate: 27.520000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 28.480000% averaged train nll: 0.817441 averaged train loss: 1.219681
# At minibatch 24400, batch loss 1.465485, batch nll 1.062013, batch error rate 28.000000%
# At minibatch 24800, batch loss 1.283688, batch nll 0.878940, batch error rate 40.000000%
# At minibatch 25200, batch loss 1.104935, batch nll 0.701639, batch error rate 32.000000%
# At minibatch 25600, batch loss 0.984182, batch nll 0.581031, batch error rate 24.000000%
# After epoch 16: valid_err_rate: 25.720000% currently going to do 25 epochs
# After epoch 16: averaged train_err_rate: 27.417500% averaged train nll: 0.785870 averaged train loss: 1.189736
# At minibatch 26000, batch loss 1.363899, batch nll 0.958301, batch error rate 32.000000%
# At minibatch 26400, batch loss 1.489802, batch nll 1.083830, batch error rate 36.000000%
# At minibatch 26800, batch loss 1.145444, batch nll 0.740478, batch error rate 28.000000%
# At minibatch 27200, batch loss 1.457875, batch nll 1.051734, batch error rate 48.000000%
# After epoch 17: valid_err_rate: 24.620000% currently going to do 26 epochs
# After epoch 17: averaged train_err_rate: 27.035000% averaged train nll: 0.775787 averaged train loss: 1.181346
# At minibatch 27600, batch loss 1.107579, batch nll 0.700701, batch error rate 28.000000%
# At minibatch 28000, batch loss 1.085581, batch nll 0.678092, batch error rate 16.000000%
# At minibatch 28400, batch loss 1.381473, batch nll 0.972854, batch error rate 24.000000%
# At minibatch 28800, batch loss 0.829609, batch nll 0.422075, batch error rate 8.000000%
# After epoch 18: valid_err_rate: 23.990000% currently going to do 28 epochs
# After epoch 18: averaged train_err_rate: 26.372500% averaged train nll: 0.759203 averaged train loss: 1.166669
# At minibatch 29200, batch loss 1.225726, batch nll 0.816925, batch error rate 28.000000%
# At minibatch 29600, batch loss 1.511395, batch nll 1.101850, batch error rate 40.000000%
# At minibatch 30000, batch loss 1.163436, batch nll 0.753532, batch error rate 28.000000%
# At minibatch 30400, batch loss 1.118156, batch nll 0.709318, batch error rate 24.000000%
# After epoch 19: valid_err_rate: 26.480000% currently going to do 28 epochs
# After epoch 19: averaged train_err_rate: 25.757500% averaged train nll: 0.736473 averaged train loss: 1.145399
# At minibatch 30800, batch loss 1.235271, batch nll 0.824206, batch error rate 28.000000%
# At minibatch 31200, batch loss 1.238065, batch nll 0.826952, batch error rate 36.000000%
# At minibatch 31600, batch loss 1.527991, batch nll 1.116930, batch error rate 40.000000%
# At minibatch 32000, batch loss 1.412953, batch nll 1.002943, batch error rate 32.000000%
# After epoch 20: valid_err_rate: 24.390000% currently going to do 28 epochs
# After epoch 20: averaged train_err_rate: 25.467500% averaged train nll: 0.727759 averaged train loss: 1.138259
# At minibatch 32400, batch loss 1.386842, batch nll 0.974379, batch error rate 40.000000%
# At minibatch 32800, batch loss 1.127690, batch nll 0.716512, batch error rate 28.000000%
# At minibatch 33200, batch loss 1.214756, batch nll 0.805484, batch error rate 20.000000%
# At minibatch 33600, batch loss 1.275893, batch nll 0.865924, batch error rate 36.000000%
# After epoch 21: valid_err_rate: 24.140000% currently going to do 28 epochs
# After epoch 21: averaged train_err_rate: 24.885000% averaged train nll: 0.712969 averaged train loss: 1.123816
# At minibatch 34000, batch loss 1.135009, batch nll 0.721661, batch error rate 28.000000%
# At minibatch 34400, batch loss 0.883499, batch nll 0.469489, batch error rate 24.000000%
# At minibatch 34800, batch loss 1.291525, batch nll 0.878456, batch error rate 28.000000%
# At minibatch 35200, batch loss 0.989275, batch nll 0.576226, batch error rate 20.000000%
# After epoch 22: valid_err_rate: 23.430000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 24.547500% averaged train nll: 0.698476 averaged train loss: 1.111634
# At minibatch 35600, batch loss 1.180726, batch nll 0.767870, batch error rate 40.000000%
# At minibatch 36000, batch loss 1.275089, batch nll 0.860712, batch error rate 28.000000%
# At minibatch 36400, batch loss 0.967180, batch nll 0.554353, batch error rate 16.000000%
# At minibatch 36800, batch loss 1.014990, batch nll 0.602301, batch error rate 20.000000%
# After epoch 23: valid_err_rate: 22.900000% currently going to do 35 epochs
# After epoch 23: averaged train_err_rate: 23.987500% averaged train nll: 0.690353 averaged train loss: 1.103729
# At minibatch 37200, batch loss 0.811327, batch nll 0.397554, batch error rate 12.000000%
# At minibatch 37600, batch loss 1.098095, batch nll 0.683430, batch error rate 24.000000%
# At minibatch 38000, batch loss 0.818151, batch nll 0.402967, batch error rate 8.000000%
# At minibatch 38400, batch loss 0.990592, batch nll 0.576047, batch error rate 24.000000%
# After epoch 24: valid_err_rate: 24.440000% currently going to do 35 epochs
# After epoch 24: averaged train_err_rate: 23.750000% averaged train nll: 0.677134 averaged train loss: 1.091667
# At minibatch 38800, batch loss 1.085516, batch nll 0.669572, batch error rate 24.000000%
# At minibatch 39200, batch loss 0.976106, batch nll 0.559384, batch error rate 20.000000%
# At minibatch 39600, batch loss 1.202332, batch nll 0.785963, batch error rate 24.000000%
# At minibatch 40000, batch loss 0.902489, batch nll 0.486759, batch error rate 16.000000%
# After epoch 25: valid_err_rate: 23.690000% currently going to do 35 epochs
# After epoch 25: averaged train_err_rate: 23.487500% averaged train nll: 0.664593 averaged train loss: 1.080604
# At minibatch 40400, batch loss 1.058619, batch nll 0.641694, batch error rate 28.000000%
# At minibatch 40800, batch loss 1.113963, batch nll 0.695202, batch error rate 24.000000%
# At minibatch 41200, batch loss 0.957301, batch nll 0.539949, batch error rate 20.000000%
# At minibatch 41600, batch loss 1.198503, batch nll 0.781429, batch error rate 24.000000%
# After epoch 26: valid_err_rate: 21.370000% currently going to do 40 epochs
# After epoch 26: averaged train_err_rate: 22.885000% averaged train nll: 0.652116 averaged train loss: 1.069531
# At minibatch 42000, batch loss 1.194871, batch nll 0.775994, batch error rate 32.000000%
# At minibatch 42400, batch loss 1.056117, batch nll 0.636535, batch error rate 20.000000%
# At minibatch 42800, batch loss 1.017168, batch nll 0.598293, batch error rate 20.000000%
# At minibatch 43200, batch loss 1.163969, batch nll 0.746846, batch error rate 24.000000%
# After epoch 27: valid_err_rate: 21.990000% currently going to do 40 epochs
# After epoch 27: averaged train_err_rate: 22.305000% averaged train nll: 0.640131 averaged train loss: 1.058898
# At minibatch 43600, batch loss 1.386433, batch nll 0.967149, batch error rate 32.000000%
# At minibatch 44000, batch loss 1.172329, batch nll 0.752470, batch error rate 32.000000%
# At minibatch 44400, batch loss 1.126785, batch nll 0.707781, batch error rate 32.000000%
# At minibatch 44800, batch loss 1.026519, batch nll 0.606672, batch error rate 28.000000%
# After epoch 28: valid_err_rate: 22.200000% currently going to do 40 epochs
# After epoch 28: averaged train_err_rate: 22.222500% averaged train nll: 0.637309 averaged train loss: 1.056568
# At minibatch 45200, batch loss 1.304973, batch nll 0.882598, batch error rate 36.000000%
# At minibatch 45600, batch loss 0.923606, batch nll 0.501978, batch error rate 16.000000%
# At minibatch 46000, batch loss 1.044168, batch nll 0.623403, batch error rate 20.000000%
# At minibatch 46400, batch loss 1.122303, batch nll 0.702668, batch error rate 24.000000%
# After epoch 29: valid_err_rate: 21.140000% currently going to do 44 epochs
# After epoch 29: averaged train_err_rate: 21.757500% averaged train nll: 0.629177 averaged train loss: 1.050279
# At minibatch 46800, batch loss 0.936391, batch nll 0.514527, batch error rate 16.000000%
# At minibatch 47200, batch loss 0.829322, batch nll 0.407297, batch error rate 12.000000%
# At minibatch 47600, batch loss 1.004860, batch nll 0.582983, batch error rate 12.000000%
# At minibatch 48000, batch loss 0.703680, batch nll 0.281811, batch error rate 8.000000%
# After epoch 30: valid_err_rate: 22.310000% currently going to do 44 epochs
# After epoch 30: averaged train_err_rate: 21.467500% averaged train nll: 0.614404 averaged train loss: 1.036261
# At minibatch 48400, batch loss 0.866777, batch nll 0.442984, batch error rate 16.000000%
# At minibatch 48800, batch loss 1.051260, batch nll 0.627377, batch error rate 24.000000%
# At minibatch 49200, batch loss 1.164220, batch nll 0.740409, batch error rate 24.000000%
# At minibatch 49600, batch loss 0.857150, batch nll 0.434202, batch error rate 12.000000%
# After epoch 31: valid_err_rate: 20.490000% currently going to do 47 epochs
# After epoch 31: averaged train_err_rate: 21.170000% averaged train nll: 0.608644 averaged train loss: 1.032209
# At minibatch 50000, batch loss 1.051792, batch nll 0.626512, batch error rate 20.000000%
# At minibatch 50400, batch loss 1.206979, batch nll 0.782339, batch error rate 20.000000%
# At minibatch 50800, batch loss 0.959874, batch nll 0.534867, batch error rate 16.000000%
# At minibatch 51200, batch loss 0.950174, batch nll 0.524690, batch error rate 16.000000%
# After epoch 32: valid_err_rate: 21.480000% currently going to do 47 epochs
# After epoch 32: averaged train_err_rate: 21.065000% averaged train nll: 0.599272 averaged train loss: 1.024052
# At minibatch 51600, batch loss 0.821325, batch nll 0.394002, batch error rate 12.000000%
# At minibatch 52000, batch loss 1.028875, batch nll 0.601789, batch error rate 20.000000%
# At minibatch 52400, batch loss 0.966125, batch nll 0.539523, batch error rate 28.000000%
# At minibatch 52800, batch loss 1.005898, batch nll 0.580793, batch error rate 20.000000%
# After epoch 33: valid_err_rate: 20.310000% currently going to do 50 epochs
# After epoch 33: averaged train_err_rate: 20.517500% averaged train nll: 0.592750 averaged train loss: 1.019238
# At minibatch 53200, batch loss 1.164023, batch nll 0.736782, batch error rate 24.000000%
# At minibatch 53600, batch loss 0.974067, batch nll 0.545797, batch error rate 16.000000%
# At minibatch 54000, batch loss 1.256727, batch nll 0.829732, batch error rate 32.000000%
# At minibatch 54400, batch loss 0.905943, batch nll 0.478556, batch error rate 16.000000%
# After epoch 34: valid_err_rate: 22.920000% currently going to do 50 epochs
# After epoch 34: averaged train_err_rate: 20.305000% averaged train nll: 0.582941 averaged train loss: 1.010195
# At minibatch 54800, batch loss 0.833228, batch nll 0.404035, batch error rate 12.000000%
# At minibatch 55200, batch loss 1.093170, batch nll 0.664892, batch error rate 24.000000%
# At minibatch 55600, batch loss 0.804364, batch nll 0.376100, batch error rate 12.000000%
# At minibatch 56000, batch loss 1.143233, batch nll 0.714012, batch error rate 12.000000%
# After epoch 35: valid_err_rate: 20.630000% currently going to do 50 epochs
# After epoch 35: averaged train_err_rate: 20.125000% averaged train nll: 0.576356 averaged train loss: 1.005041
# At minibatch 56400, batch loss 1.085016, batch nll 0.654045, batch error rate 32.000000%
# At minibatch 56800, batch loss 0.997579, batch nll 0.566434, batch error rate 20.000000%
# At minibatch 57200, batch loss 0.889978, batch nll 0.458496, batch error rate 20.000000%
# At minibatch 57600, batch loss 1.007296, batch nll 0.576166, batch error rate 20.000000%
# After epoch 36: valid_err_rate: 22.330000% currently going to do 50 epochs
# After epoch 36: averaged train_err_rate: 19.887500% averaged train nll: 0.569532 averaged train loss: 1.000359
# At minibatch 58000, batch loss 1.177479, batch nll 0.745264, batch error rate 28.000000%
# At minibatch 58400, batch loss 0.821514, batch nll 0.389385, batch error rate 8.000000%
# At minibatch 58800, batch loss 1.037961, batch nll 0.605854, batch error rate 20.000000%
# At minibatch 59200, batch loss 1.115579, batch nll 0.684804, batch error rate 28.000000%
# After epoch 37: valid_err_rate: 20.300000% currently going to do 56 epochs
# After epoch 37: averaged train_err_rate: 19.807500% averaged train nll: 0.562801 averaged train loss: 0.994612
# At minibatch 59600, batch loss 1.130425, batch nll 0.697409, batch error rate 24.000000%
# At minibatch 60000, batch loss 0.927336, batch nll 0.494342, batch error rate 16.000000%
# At minibatch 60400, batch loss 1.118046, batch nll 0.685482, batch error rate 24.000000%
# At minibatch 60800, batch loss 1.040508, batch nll 0.608439, batch error rate 24.000000%
# After epoch 38: valid_err_rate: 20.110000% currently going to do 58 epochs
# After epoch 38: averaged train_err_rate: 19.550000% averaged train nll: 0.554897 averaged train loss: 0.987501
# At minibatch 61200, batch loss 0.915662, batch nll 0.482114, batch error rate 16.000000%
# At minibatch 61600, batch loss 0.964390, batch nll 0.530417, batch error rate 28.000000%
# At minibatch 62000, batch loss 1.048211, batch nll 0.613744, batch error rate 24.000000%
# At minibatch 62400, batch loss 1.248996, batch nll 0.815082, batch error rate 36.000000%
# After epoch 39: valid_err_rate: 21.300000% currently going to do 58 epochs
# After epoch 39: averaged train_err_rate: 19.000000% averaged train nll: 0.546997 averaged train loss: 0.980613
# At minibatch 62800, batch loss 0.863984, batch nll 0.428591, batch error rate 12.000000%
# At minibatch 63200, batch loss 0.695013, batch nll 0.258833, batch error rate 8.000000%
# At minibatch 63600, batch loss 0.741571, batch nll 0.306114, batch error rate 8.000000%
# At minibatch 64000, batch loss 0.974599, batch nll 0.539051, batch error rate 28.000000%
# After epoch 40: valid_err_rate: 19.510000% currently going to do 61 epochs
# After epoch 40: averaged train_err_rate: 18.980000% averaged train nll: 0.544190 averaged train loss: 0.979399
# At minibatch 64400, batch loss 1.254174, batch nll 0.817974, batch error rate 40.000000%
# At minibatch 64800, batch loss 1.378860, batch nll 0.942405, batch error rate 32.000000%
# At minibatch 65200, batch loss 1.064990, batch nll 0.628550, batch error rate 20.000000%
# At minibatch 65600, batch loss 1.056158, batch nll 0.619379, batch error rate 28.000000%
# After epoch 41: valid_err_rate: 21.300000% currently going to do 61 epochs
# After epoch 41: averaged train_err_rate: 18.855000% averaged train nll: 0.539812 averaged train loss: 0.976274
# At minibatch 66000, batch loss 0.947149, batch nll 0.508974, batch error rate 28.000000%
# At minibatch 66400, batch loss 0.924465, batch nll 0.486696, batch error rate 20.000000%
# At minibatch 66800, batch loss 1.063335, batch nll 0.626278, batch error rate 24.000000%
# At minibatch 67200, batch loss 0.874588, batch nll 0.436938, batch error rate 28.000000%
# After epoch 42: valid_err_rate: 19.980000% currently going to do 61 epochs
# After epoch 42: averaged train_err_rate: 18.582500% averaged train nll: 0.532957 averaged train loss: 0.970629
# At minibatch 67600, batch loss 0.961256, batch nll 0.522477, batch error rate 20.000000%
# At minibatch 68000, batch loss 0.814257, batch nll 0.375748, batch error rate 8.000000%
# At minibatch 68400, batch loss 0.994350, batch nll 0.556121, batch error rate 24.000000%
# At minibatch 68800, batch loss 1.425290, batch nll 0.987030, batch error rate 16.000000%
# After epoch 43: valid_err_rate: 20.990000% currently going to do 61 epochs
# After epoch 43: averaged train_err_rate: 18.192500% averaged train nll: 0.527659 averaged train loss: 0.966032
# At minibatch 69200, batch loss 1.105184, batch nll 0.665286, batch error rate 20.000000%
# At minibatch 69600, batch loss 0.781979, batch nll 0.341994, batch error rate 8.000000%
# At minibatch 70000, batch loss 0.890303, batch nll 0.450778, batch error rate 20.000000%
# At minibatch 70400, batch loss 0.821565, batch nll 0.382336, batch error rate 12.000000%
# After epoch 44: valid_err_rate: 19.460000% currently going to do 67 epochs
# After epoch 44: averaged train_err_rate: 18.067500% averaged train nll: 0.519935 averaged train loss: 0.959514
# At minibatch 70800, batch loss 1.199702, batch nll 0.759794, batch error rate 32.000000%
# At minibatch 71200, batch loss 0.805981, batch nll 0.365535, batch error rate 8.000000%
# At minibatch 71600, batch loss 0.920853, batch nll 0.480741, batch error rate 24.000000%
# At minibatch 72000, batch loss 0.861086, batch nll 0.421477, batch error rate 28.000000%
# After epoch 45: valid_err_rate: 20.360000% currently going to do 67 epochs
# After epoch 45: averaged train_err_rate: 17.992500% averaged train nll: 0.518476 averaged train loss: 0.958469
# At minibatch 72400, batch loss 1.005949, batch nll 0.565074, batch error rate 20.000000%
# At minibatch 72800, batch loss 0.907622, batch nll 0.466223, batch error rate 8.000000%
# At minibatch 73200, batch loss 0.701475, batch nll 0.260438, batch error rate 4.000000%
# At minibatch 73600, batch loss 0.868058, batch nll 0.426800, batch error rate 20.000000%
# After epoch 46: valid_err_rate: 19.920000% currently going to do 67 epochs
# After epoch 46: averaged train_err_rate: 17.812500% averaged train nll: 0.509610 averaged train loss: 0.950452
# At minibatch 74000, batch loss 0.782653, batch nll 0.340556, batch error rate 16.000000%
# At minibatch 74400, batch loss 0.945244, batch nll 0.502516, batch error rate 12.000000%
# At minibatch 74800, batch loss 1.036297, batch nll 0.593191, batch error rate 20.000000%
# At minibatch 75200, batch loss 0.845791, batch nll 0.403190, batch error rate 20.000000%
# After epoch 47: valid_err_rate: 19.540000% currently going to do 67 epochs
# After epoch 47: averaged train_err_rate: 17.520000% averaged train nll: 0.505384 averaged train loss: 0.947898
# At minibatch 75600, batch loss 1.066684, batch nll 0.622870, batch error rate 28.000000%
# At minibatch 76000, batch loss 0.827618, batch nll 0.383200, batch error rate 16.000000%
# At minibatch 76400, batch loss 1.210697, batch nll 0.765772, batch error rate 36.000000%
# At minibatch 76800, batch loss 0.727319, batch nll 0.282959, batch error rate 8.000000%
# After epoch 48: valid_err_rate: 19.740000% currently going to do 67 epochs
# After epoch 48: averaged train_err_rate: 17.167500% averaged train nll: 0.492109 averaged train loss: 0.936277
# At minibatch 77200, batch loss 0.803447, batch nll 0.358649, batch error rate 4.000000%
# At minibatch 77600, batch loss 0.789565, batch nll 0.344264, batch error rate 12.000000%
# At minibatch 78000, batch loss 0.897056, batch nll 0.451763, batch error rate 16.000000%
# At minibatch 78400, batch loss 0.829242, batch nll 0.384535, batch error rate 24.000000%
# After epoch 49: valid_err_rate: 19.770000% currently going to do 67 epochs
# After epoch 49: averaged train_err_rate: 17.122500% averaged train nll: 0.495719 averaged train loss: 0.940526
# At minibatch 78800, batch loss 0.786246, batch nll 0.340360, batch error rate 12.000000%
# At minibatch 79200, batch loss 0.927195, batch nll 0.480664, batch error rate 12.000000%
# At minibatch 79600, batch loss 0.906031, batch nll 0.459514, batch error rate 24.000000%
# At minibatch 80000, batch loss 0.952821, batch nll 0.507037, batch error rate 8.000000%
# After epoch 50: valid_err_rate: 20.430000% currently going to do 67 epochs
# After epoch 50: averaged train_err_rate: 16.832500% averaged train nll: 0.486318 averaged train loss: 0.932294
# At minibatch 80400, batch loss 1.266001, batch nll 0.818610, batch error rate 24.000000%
# At minibatch 80800, batch loss 0.835373, batch nll 0.387207, batch error rate 24.000000%
# At minibatch 81200, batch loss 0.837090, batch nll 0.389420, batch error rate 16.000000%
# At minibatch 81600, batch loss 0.833832, batch nll 0.386582, batch error rate 8.000000%
# After epoch 51: valid_err_rate: 19.130000% currently going to do 77 epochs
# After epoch 51: averaged train_err_rate: 16.630000% averaged train nll: 0.484633 averaged train loss: 0.932182
# At minibatch 82000, batch loss 1.057438, batch nll 0.609712, batch error rate 20.000000%
# At minibatch 82400, batch loss 0.786013, batch nll 0.338316, batch error rate 12.000000%
# At minibatch 82800, batch loss 0.737718, batch nll 0.289877, batch error rate 8.000000%
# At minibatch 83200, batch loss 1.028682, batch nll 0.581057, batch error rate 24.000000%
# After epoch 52: valid_err_rate: 20.420000% currently going to do 77 epochs
# After epoch 52: averaged train_err_rate: 16.625000% averaged train nll: 0.478634 averaged train loss: 0.926376
# At minibatch 83600, batch loss 0.937773, batch nll 0.489819, batch error rate 20.000000%
# At minibatch 84000, batch loss 0.916390, batch nll 0.468461, batch error rate 16.000000%
# At minibatch 84400, batch loss 0.825076, batch nll 0.377061, batch error rate 8.000000%
# At minibatch 84800, batch loss 0.707063, batch nll 0.258918, batch error rate 8.000000%
# After epoch 53: valid_err_rate: 19.080000% currently going to do 80 epochs
# After epoch 53: averaged train_err_rate: 16.515000% averaged train nll: 0.476052 averaged train loss: 0.924163
# At minibatch 85200, batch loss 1.034754, batch nll 0.585930, batch error rate 16.000000%
# At minibatch 85600, batch loss 0.919199, batch nll 0.469755, batch error rate 16.000000%
# At minibatch 86000, batch loss 0.872179, batch nll 0.422651, batch error rate 16.000000%
# At minibatch 86400, batch loss 1.187069, batch nll 0.737843, batch error rate 20.000000%
# After epoch 54: valid_err_rate: 19.250000% currently going to do 80 epochs
# After epoch 54: averaged train_err_rate: 16.477500% averaged train nll: 0.472510 averaged train loss: 0.921742
# At minibatch 86800, batch loss 1.000646, batch nll 0.549785, batch error rate 20.000000%
# At minibatch 87200, batch loss 1.053990, batch nll 0.603218, batch error rate 20.000000%
# At minibatch 87600, batch loss 0.818220, batch nll 0.367116, batch error rate 12.000000%
# At minibatch 88000, batch loss 1.003409, batch nll 0.552439, batch error rate 16.000000%
# After epoch 55: valid_err_rate: 19.100000% currently going to do 80 epochs
# After epoch 55: averaged train_err_rate: 16.175000% averaged train nll: 0.463948 averaged train loss: 0.914674
# At minibatch 88400, batch loss 0.806277, batch nll 0.354513, batch error rate 12.000000%
# At minibatch 88800, batch loss 0.984242, batch nll 0.532507, batch error rate 16.000000%
# At minibatch 89200, batch loss 0.803550, batch nll 0.351356, batch error rate 16.000000%
# At minibatch 89600, batch loss 1.201800, batch nll 0.749807, batch error rate 28.000000%
# After epoch 56: valid_err_rate: 19.020000% currently going to do 85 epochs
# After epoch 56: averaged train_err_rate: 15.992500% averaged train nll: 0.461585 averaged train loss: 0.913501
# At minibatch 90000, batch loss 1.053698, batch nll 0.601078, batch error rate 20.000000%
# At minibatch 90400, batch loss 1.168553, batch nll 0.715864, batch error rate 32.000000%
# At minibatch 90800, batch loss 1.041835, batch nll 0.588827, batch error rate 20.000000%
# At minibatch 91200, batch loss 0.903245, batch nll 0.450528, batch error rate 16.000000%
# After epoch 57: valid_err_rate: 18.750000% currently going to do 86 epochs
# After epoch 57: averaged train_err_rate: 15.757500% averaged train nll: 0.458439 averaged train loss: 0.911133
# At minibatch 91600, batch loss 0.826356, batch nll 0.372503, batch error rate 12.000000%
# At minibatch 92000, batch loss 0.926376, batch nll 0.472725, batch error rate 20.000000%
# At minibatch 92400, batch loss 1.010402, batch nll 0.556613, batch error rate 24.000000%
# At minibatch 92800, batch loss 0.862681, batch nll 0.409223, batch error rate 20.000000%
# After epoch 58: valid_err_rate: 19.070000% currently going to do 86 epochs
# After epoch 58: averaged train_err_rate: 15.725000% averaged train nll: 0.455215 averaged train loss: 0.908847
# At minibatch 93200, batch loss 1.078686, batch nll 0.623846, batch error rate 20.000000%
# At minibatch 93600, batch loss 0.779997, batch nll 0.324931, batch error rate 12.000000%
# At minibatch 94000, batch loss 0.838382, batch nll 0.383099, batch error rate 16.000000%
# At minibatch 94400, batch loss 0.894066, batch nll 0.439015, batch error rate 20.000000%
# After epoch 59: valid_err_rate: 19.430000% currently going to do 86 epochs
# After epoch 59: averaged train_err_rate: 15.557500% averaged train nll: 0.449262 averaged train loss: 0.904123
# At minibatch 94800, batch loss 0.945085, batch nll 0.489456, batch error rate 20.000000%
# At minibatch 95200, batch loss 0.877517, batch nll 0.421789, batch error rate 16.000000%
# At minibatch 95600, batch loss 0.880756, batch nll 0.425423, batch error rate 20.000000%
# At minibatch 96000, batch loss 1.081927, batch nll 0.626290, batch error rate 24.000000%
# After epoch 60: valid_err_rate: 19.220000% currently going to do 86 epochs
# After epoch 60: averaged train_err_rate: 15.245000% averaged train nll: 0.445753 averaged train loss: 0.901439
# At minibatch 96400, batch loss 0.692499, batch nll 0.236196, batch error rate 8.000000%
# At minibatch 96800, batch loss 0.714174, batch nll 0.257999, batch error rate 8.000000%
# At minibatch 97200, batch loss 0.788249, batch nll 0.331715, batch error rate 8.000000%
# At minibatch 97600, batch loss 0.904394, batch nll 0.447798, batch error rate 16.000000%
# After epoch 61: valid_err_rate: 18.290000% currently going to do 92 epochs
# After epoch 61: averaged train_err_rate: 15.317500% averaged train nll: 0.446133 averaged train loss: 0.902466
# At minibatch 98000, batch loss 0.826616, batch nll 0.368876, batch error rate 12.000000%
# At minibatch 98400, batch loss 0.918849, batch nll 0.460772, batch error rate 20.000000%
# At minibatch 98800, batch loss 1.107103, batch nll 0.648963, batch error rate 32.000000%
# At minibatch 99200, batch loss 0.888561, batch nll 0.430268, batch error rate 12.000000%
# After epoch 62: valid_err_rate: 18.120000% currently going to do 94 epochs
# After epoch 62: averaged train_err_rate: 14.977500% averaged train nll: 0.434768 averaged train loss: 0.892656
# At minibatch 99600, batch loss 0.672390, batch nll 0.213586, batch error rate 8.000000%
# At minibatch 100000, batch loss 1.018729, batch nll 0.559550, batch error rate 24.000000%
# At minibatch 100400, batch loss 0.689369, batch nll 0.229975, batch error rate 4.000000%
# At minibatch 100800, batch loss 0.949046, batch nll 0.490182, batch error rate 12.000000%
# After epoch 63: valid_err_rate: 18.160000% currently going to do 94 epochs
# After epoch 63: averaged train_err_rate: 14.907500% averaged train nll: 0.432295 averaged train loss: 0.891305
# At minibatch 101200, batch loss 0.782651, batch nll 0.322987, batch error rate 16.000000%
# At minibatch 101600, batch loss 0.805263, batch nll 0.344895, batch error rate 16.000000%
# At minibatch 102000, batch loss 0.840136, batch nll 0.379835, batch error rate 12.000000%
# At minibatch 102400, batch loss 1.039618, batch nll 0.580107, batch error rate 20.000000%
# After epoch 64: valid_err_rate: 19.290000% currently going to do 94 epochs
# After epoch 64: averaged train_err_rate: 14.640000% averaged train nll: 0.429120 averaged train loss: 0.889056
# At minibatch 102800, batch loss 0.908209, batch nll 0.447934, batch error rate 12.000000%
# At minibatch 103200, batch loss 0.660948, batch nll 0.200147, batch error rate 8.000000%
# At minibatch 103600, batch loss 0.925789, batch nll 0.464906, batch error rate 12.000000%
# At minibatch 104000, batch loss 0.863466, batch nll 0.403088, batch error rate 16.000000%
# After epoch 65: valid_err_rate: 18.510000% currently going to do 94 epochs
# After epoch 65: averaged train_err_rate: 14.627500% averaged train nll: 0.427428 averaged train loss: 0.887857
# At minibatch 104400, batch loss 1.014080, batch nll 0.552941, batch error rate 20.000000%
# At minibatch 104800, batch loss 1.020882, batch nll 0.559549, batch error rate 24.000000%
# At minibatch 105200, batch loss 1.018735, batch nll 0.557278, batch error rate 20.000000%
# At minibatch 105600, batch loss 0.680410, batch nll 0.218989, batch error rate 8.000000%
# After epoch 66: valid_err_rate: 18.330000% currently going to do 94 epochs
# After epoch 66: averaged train_err_rate: 14.385000% averaged train nll: 0.419568 averaged train loss: 0.880741
# At minibatch 106000, batch loss 0.759133, batch nll 0.296942, batch error rate 12.000000%
# At minibatch 106400, batch loss 0.929506, batch nll 0.467613, batch error rate 16.000000%
# At minibatch 106800, batch loss 0.864060, batch nll 0.401976, batch error rate 24.000000%
# At minibatch 107200, batch loss 1.096003, batch nll 0.634158, batch error rate 28.000000%
# After epoch 67: valid_err_rate: 18.530000% currently going to do 94 epochs
# After epoch 67: averaged train_err_rate: 14.402500% averaged train nll: 0.422359 averaged train loss: 0.884315
# At minibatch 107600, batch loss 0.911867, batch nll 0.449662, batch error rate 24.000000%
# At minibatch 108000, batch loss 1.164473, batch nll 0.702287, batch error rate 24.000000%
# At minibatch 108400, batch loss 0.964157, batch nll 0.501969, batch error rate 20.000000%
# At minibatch 108800, batch loss 0.655282, batch nll 0.193135, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 17.890000% currently going to do 103 epochs
# After epoch 68: averaged train_err_rate: 14.347500% averaged train nll: 0.417769 averaged train loss: 0.879971
# At minibatch 109200, batch loss 1.041198, batch nll 0.578433, batch error rate 20.000000%
# At minibatch 109600, batch loss 0.999344, batch nll 0.536091, batch error rate 16.000000%
# At minibatch 110000, batch loss 0.751372, batch nll 0.287920, batch error rate 12.000000%
# At minibatch 110400, batch loss 0.772646, batch nll 0.308590, batch error rate 4.000000%
# After epoch 69: valid_err_rate: 17.940000% currently going to do 103 epochs
# After epoch 69: averaged train_err_rate: 13.770000% averaged train nll: 0.407364 averaged train loss: 0.870637
# At minibatch 110800, batch loss 0.860708, batch nll 0.396434, batch error rate 12.000000%
# At minibatch 111200, batch loss 0.763493, batch nll 0.299344, batch error rate 4.000000%
# At minibatch 111600, batch loss 0.878590, batch nll 0.414312, batch error rate 20.000000%
# At minibatch 112000, batch loss 0.726917, batch nll 0.262615, batch error rate 8.000000%
# After epoch 70: valid_err_rate: 18.420000% currently going to do 103 epochs
# After epoch 70: averaged train_err_rate: 14.002500% averaged train nll: 0.406454 averaged train loss: 0.870672
# At minibatch 112400, batch loss 0.760821, batch nll 0.295936, batch error rate 16.000000%
# At minibatch 112800, batch loss 1.170852, batch nll 0.705884, batch error rate 20.000000%
# At minibatch 113200, batch loss 1.081543, batch nll 0.616303, batch error rate 28.000000%
# At minibatch 113600, batch loss 0.820995, batch nll 0.355993, batch error rate 8.000000%
# After epoch 71: valid_err_rate: 18.870000% currently going to do 103 epochs
# After epoch 71: averaged train_err_rate: 13.925000% averaged train nll: 0.408688 averaged train loss: 0.873626
# At minibatch 114000, batch loss 0.930509, batch nll 0.464944, batch error rate 20.000000%
# At minibatch 114400, batch loss 0.787333, batch nll 0.321245, batch error rate 16.000000%
# At minibatch 114800, batch loss 0.996761, batch nll 0.530913, batch error rate 16.000000%
# At minibatch 115200, batch loss 0.869511, batch nll 0.403871, batch error rate 16.000000%
# After epoch 72: valid_err_rate: 18.430000% currently going to do 103 epochs
# After epoch 72: averaged train_err_rate: 13.667500% averaged train nll: 0.399515 averaged train loss: 0.865226
# At minibatch 115600, batch loss 1.222358, batch nll 0.756020, batch error rate 32.000000%
# At minibatch 116000, batch loss 0.870133, batch nll 0.403760, batch error rate 16.000000%
# At minibatch 116400, batch loss 1.053970, batch nll 0.587528, batch error rate 24.000000%
# At minibatch 116800, batch loss 0.574217, batch nll 0.107752, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 17.960000% currently going to do 103 epochs
# After epoch 73: averaged train_err_rate: 13.575000% averaged train nll: 0.398706 averaged train loss: 0.865066
# At minibatch 117200, batch loss 0.978826, batch nll 0.512092, batch error rate 24.000000%
# At minibatch 117600, batch loss 0.843990, batch nll 0.377010, batch error rate 12.000000%
# At minibatch 118000, batch loss 1.042971, batch nll 0.576124, batch error rate 16.000000%
# At minibatch 118400, batch loss 0.697671, batch nll 0.230823, batch error rate 12.000000%
# After epoch 74: valid_err_rate: 18.730000% currently going to do 103 epochs
# After epoch 74: averaged train_err_rate: 13.407500% averaged train nll: 0.395239 averaged train loss: 0.862053
# At minibatch 118800, batch loss 0.569315, batch nll 0.101581, batch error rate 4.000000%
# At minibatch 119200, batch loss 1.037377, batch nll 0.569411, batch error rate 16.000000%
# At minibatch 119600, batch loss 0.717797, batch nll 0.250151, batch error rate 12.000000%
# At minibatch 120000, batch loss 1.018768, batch nll 0.551413, batch error rate 16.000000%
# After epoch 75: valid_err_rate: 18.710000% currently going to do 103 epochs
# After epoch 75: averaged train_err_rate: 13.230000% averaged train nll: 0.393646 averaged train loss: 0.861283
# At minibatch 120400, batch loss 0.725446, batch nll 0.257750, batch error rate 4.000000%
# At minibatch 120800, batch loss 0.813701, batch nll 0.345585, batch error rate 16.000000%
# At minibatch 121200, batch loss 0.834472, batch nll 0.366334, batch error rate 8.000000%
# At minibatch 121600, batch loss 0.848395, batch nll 0.380253, batch error rate 16.000000%
# After epoch 76: valid_err_rate: 18.750000% currently going to do 103 epochs
# After epoch 76: averaged train_err_rate: 13.230000% averaged train nll: 0.391289 averaged train loss: 0.859309
# At minibatch 122000, batch loss 0.957130, batch nll 0.488518, batch error rate 20.000000%
# At minibatch 122400, batch loss 0.855760, batch nll 0.386739, batch error rate 12.000000%
# At minibatch 122800, batch loss 0.862142, batch nll 0.393293, batch error rate 12.000000%
# At minibatch 123200, batch loss 0.839053, batch nll 0.370724, batch error rate 12.000000%
# After epoch 77: valid_err_rate: 18.230000% currently going to do 103 epochs
# After epoch 77: averaged train_err_rate: 13.285000% averaged train nll: 0.389092 averaged train loss: 0.857788
# At minibatch 123600, batch loss 0.715980, batch nll 0.246881, batch error rate 4.000000%
# At minibatch 124000, batch loss 0.918297, batch nll 0.448535, batch error rate 8.000000%
# At minibatch 124400, batch loss 0.980608, batch nll 0.510900, batch error rate 16.000000%
# At minibatch 124800, batch loss 0.791638, batch nll 0.322138, batch error rate 12.000000%
# After epoch 78: valid_err_rate: 18.140000% currently going to do 103 epochs
# After epoch 78: averaged train_err_rate: 13.017500% averaged train nll: 0.382934 averaged train loss: 0.852300
# At minibatch 125200, batch loss 0.706153, batch nll 0.235825, batch error rate 8.000000%
# At minibatch 125600, batch loss 0.690084, batch nll 0.219657, batch error rate 12.000000%
# At minibatch 126000, batch loss 0.675054, batch nll 0.204663, batch error rate 8.000000%
# At minibatch 126400, batch loss 0.711542, batch nll 0.241239, batch error rate 4.000000%
# After epoch 79: valid_err_rate: 17.980000% currently going to do 103 epochs
# After epoch 79: averaged train_err_rate: 12.842500% averaged train nll: 0.379015 averaged train loss: 0.849278
# At minibatch 126800, batch loss 0.912119, batch nll 0.441441, batch error rate 20.000000%
# At minibatch 127200, batch loss 1.128629, batch nll 0.657403, batch error rate 20.000000%
# At minibatch 127600, batch loss 0.843295, batch nll 0.372026, batch error rate 12.000000%
# At minibatch 128000, batch loss 1.030615, batch nll 0.559480, batch error rate 28.000000%
# After epoch 80: valid_err_rate: 19.060000% currently going to do 103 epochs
# After epoch 80: averaged train_err_rate: 12.877500% averaged train nll: 0.380625 averaged train loss: 0.851551
# At minibatch 128400, batch loss 0.834597, batch nll 0.362939, batch error rate 16.000000%
# At minibatch 128800, batch loss 0.578467, batch nll 0.106123, batch error rate 0.000000%
# At minibatch 129200, batch loss 1.107126, batch nll 0.634336, batch error rate 28.000000%
# At minibatch 129600, batch loss 0.608898, batch nll 0.136471, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 19.170000% currently going to do 103 epochs
# After epoch 81: averaged train_err_rate: 12.620000% averaged train nll: 0.374240 averaged train loss: 0.846382
# At minibatch 130000, batch loss 1.074436, batch nll 0.601011, batch error rate 20.000000%
# At minibatch 130400, batch loss 0.959157, batch nll 0.485562, batch error rate 24.000000%
# At minibatch 130800, batch loss 0.700357, batch nll 0.226649, batch error rate 8.000000%
# At minibatch 131200, batch loss 0.884774, batch nll 0.411235, batch error rate 12.000000%
# After epoch 82: valid_err_rate: 19.100000% currently going to do 103 epochs
# After epoch 82: averaged train_err_rate: 12.792500% averaged train nll: 0.373148 averaged train loss: 0.846602
# At minibatch 131600, batch loss 0.891122, batch nll 0.417316, batch error rate 16.000000%
# At minibatch 132000, batch loss 0.789630, batch nll 0.315823, batch error rate 8.000000%
# At minibatch 132400, batch loss 0.713479, batch nll 0.239690, batch error rate 4.000000%
# At minibatch 132800, batch loss 1.092700, batch nll 0.619097, batch error rate 16.000000%
# After epoch 83: valid_err_rate: 18.460000% currently going to do 103 epochs
# After epoch 83: averaged train_err_rate: 12.397500% averaged train nll: 0.370122 averaged train loss: 0.843837
# At minibatch 133200, batch loss 1.052674, batch nll 0.578286, batch error rate 24.000000%
# At minibatch 133600, batch loss 1.079519, batch nll 0.604723, batch error rate 16.000000%
# At minibatch 134000, batch loss 0.886727, batch nll 0.411703, batch error rate 12.000000%
# At minibatch 134400, batch loss 0.719874, batch nll 0.245146, batch error rate 4.000000%
# After epoch 84: valid_err_rate: 18.180000% currently going to do 103 epochs
# After epoch 84: averaged train_err_rate: 12.617500% averaged train nll: 0.369034 averaged train loss: 0.843653
# At minibatch 134800, batch loss 1.086383, batch nll 0.610826, batch error rate 28.000000%
# At minibatch 135200, batch loss 1.222252, batch nll 0.747010, batch error rate 28.000000%
# At minibatch 135600, batch loss 0.809465, batch nll 0.333990, batch error rate 12.000000%
# At minibatch 136000, batch loss 0.816484, batch nll 0.340726, batch error rate 16.000000%
# After epoch 85: valid_err_rate: 17.630000% currently going to do 128 epochs
# After epoch 85: averaged train_err_rate: 12.335000% averaged train nll: 0.365644 averaged train loss: 0.841027
# At minibatch 136400, batch loss 0.777071, batch nll 0.301072, batch error rate 4.000000%
# At minibatch 136800, batch loss 0.849246, batch nll 0.372508, batch error rate 16.000000%
# At minibatch 137200, batch loss 0.757506, batch nll 0.280918, batch error rate 8.000000%
# At minibatch 137600, batch loss 0.765450, batch nll 0.288901, batch error rate 16.000000%
# After epoch 86: valid_err_rate: 18.370000% currently going to do 128 epochs
# After epoch 86: averaged train_err_rate: 12.225000% averaged train nll: 0.360739 averaged train loss: 0.837123
# At minibatch 138000, batch loss 0.783152, batch nll 0.306217, batch error rate 12.000000%
# At minibatch 138400, batch loss 0.815672, batch nll 0.338652, batch error rate 4.000000%
# At minibatch 138800, batch loss 0.747854, batch nll 0.270899, batch error rate 12.000000%
# At minibatch 139200, batch loss 0.638416, batch nll 0.161360, batch error rate 4.000000%
# After epoch 87: valid_err_rate: 18.580000% currently going to do 128 epochs
# After epoch 87: averaged train_err_rate: 12.007500% averaged train nll: 0.358015 averaged train loss: 0.834980
# At minibatch 139600, batch loss 0.643103, batch nll 0.165836, batch error rate 0.000000%
# At minibatch 140000, batch loss 0.773834, batch nll 0.296324, batch error rate 12.000000%
# At minibatch 140400, batch loss 0.810117, batch nll 0.332691, batch error rate 8.000000%
# At minibatch 140800, batch loss 0.717451, batch nll 0.240239, batch error rate 16.000000%
# After epoch 88: valid_err_rate: 17.890000% currently going to do 128 epochs
# After epoch 88: averaged train_err_rate: 12.062500% averaged train nll: 0.355241 averaged train loss: 0.832626
# At minibatch 141200, batch loss 0.865136, batch nll 0.387105, batch error rate 12.000000%
# At minibatch 141600, batch loss 0.704546, batch nll 0.226327, batch error rate 4.000000%
# At minibatch 142000, batch loss 0.648263, batch nll 0.170363, batch error rate 4.000000%
# At minibatch 142400, batch loss 0.688330, batch nll 0.210461, batch error rate 4.000000%
# After epoch 89: valid_err_rate: 17.660000% currently going to do 128 epochs
# After epoch 89: averaged train_err_rate: 11.910000% averaged train nll: 0.353726 averaged train loss: 0.831709
# At minibatch 142800, batch loss 0.967518, batch nll 0.489010, batch error rate 16.000000%
# At minibatch 143200, batch loss 0.829049, batch nll 0.350753, batch error rate 8.000000%
# At minibatch 143600, batch loss 0.772357, batch nll 0.294219, batch error rate 4.000000%
# At minibatch 144000, batch loss 1.065529, batch nll 0.587635, batch error rate 24.000000%
# After epoch 90: valid_err_rate: 18.120000% currently going to do 128 epochs
# After epoch 90: averaged train_err_rate: 11.820000% averaged train nll: 0.348942 averaged train loss: 0.827093
# At minibatch 144400, batch loss 0.821319, batch nll 0.342660, batch error rate 12.000000%
# At minibatch 144800, batch loss 0.700786, batch nll 0.222074, batch error rate 4.000000%
# At minibatch 145200, batch loss 0.790752, batch nll 0.311657, batch error rate 12.000000%
# At minibatch 145600, batch loss 0.789378, batch nll 0.310343, batch error rate 8.000000%
# After epoch 91: valid_err_rate: 17.730000% currently going to do 128 epochs
# After epoch 91: averaged train_err_rate: 11.747500% averaged train nll: 0.350578 averaged train loss: 0.829325
# At minibatch 146000, batch loss 0.886641, batch nll 0.407224, batch error rate 12.000000%
# At minibatch 146400, batch loss 0.676426, batch nll 0.196927, batch error rate 8.000000%
# At minibatch 146800, batch loss 0.913537, batch nll 0.433832, batch error rate 16.000000%
# At minibatch 147200, batch loss 0.726792, batch nll 0.247456, batch error rate 8.000000%
# After epoch 92: valid_err_rate: 18.130000% currently going to do 128 epochs
# After epoch 92: averaged train_err_rate: 11.572500% averaged train nll: 0.349266 averaged train loss: 0.828701
# At minibatch 147600, batch loss 0.716475, batch nll 0.236584, batch error rate 12.000000%
# At minibatch 148000, batch loss 0.921447, batch nll 0.441628, batch error rate 12.000000%
# At minibatch 148400, batch loss 0.767994, batch nll 0.287879, batch error rate 8.000000%
# At minibatch 148800, batch loss 0.823678, batch nll 0.344106, batch error rate 12.000000%
# After epoch 93: valid_err_rate: 18.580000% currently going to do 128 epochs
# After epoch 93: averaged train_err_rate: 11.600000% averaged train nll: 0.345647 averaged train loss: 0.825418
# At minibatch 149200, batch loss 0.892352, batch nll 0.412141, batch error rate 16.000000%
# At minibatch 149600, batch loss 0.719082, batch nll 0.239094, batch error rate 8.000000%
# At minibatch 150000, batch loss 0.926271, batch nll 0.446549, batch error rate 8.000000%
# At minibatch 150400, batch loss 0.765164, batch nll 0.285256, batch error rate 12.000000%
# After epoch 94: valid_err_rate: 17.850000% currently going to do 128 epochs
# After epoch 94: averaged train_err_rate: 11.577500% averaged train nll: 0.343718 averaged train loss: 0.823595
# At minibatch 150800, batch loss 0.690083, batch nll 0.209262, batch error rate 4.000000%
# At minibatch 151200, batch loss 0.835880, batch nll 0.354929, batch error rate 12.000000%
# At minibatch 151600, batch loss 0.923090, batch nll 0.441859, batch error rate 16.000000%
# At minibatch 152000, batch loss 0.909490, batch nll 0.428104, batch error rate 12.000000%
# After epoch 95: valid_err_rate: 17.900000% currently going to do 128 epochs
# After epoch 95: averaged train_err_rate: 11.272500% averaged train nll: 0.335338 averaged train loss: 0.816265
# At minibatch 152400, batch loss 0.809510, batch nll 0.327903, batch error rate 8.000000%
# At minibatch 152800, batch loss 0.916778, batch nll 0.435122, batch error rate 12.000000%
# At minibatch 153200, batch loss 0.857225, batch nll 0.375673, batch error rate 24.000000%
# At minibatch 153600, batch loss 0.866973, batch nll 0.385467, batch error rate 8.000000%
# After epoch 96: valid_err_rate: 18.040000% currently going to do 128 epochs
# After epoch 96: averaged train_err_rate: 11.112500% averaged train nll: 0.336639 averaged train loss: 0.818265
# At minibatch 154000, batch loss 0.752799, batch nll 0.270923, batch error rate 12.000000%
# At minibatch 154400, batch loss 0.756335, batch nll 0.274261, batch error rate 8.000000%
# At minibatch 154800, batch loss 0.700363, batch nll 0.218266, batch error rate 4.000000%
# At minibatch 155200, batch loss 0.898505, batch nll 0.416749, batch error rate 16.000000%
# After epoch 97: valid_err_rate: 17.610000% currently going to do 146 epochs
# After epoch 97: averaged train_err_rate: 11.032500% averaged train nll: 0.333457 averaged train loss: 0.815367
# At minibatch 155600, batch loss 0.645659, batch nll 0.163400, batch error rate 4.000000%
# At minibatch 156000, batch loss 0.997996, batch nll 0.515211, batch error rate 16.000000%
# At minibatch 156400, batch loss 0.690637, batch nll 0.208151, batch error rate 8.000000%
# At minibatch 156800, batch loss 1.000274, batch nll 0.518060, batch error rate 16.000000%
# After epoch 98: valid_err_rate: 17.910000% currently going to do 146 epochs
# After epoch 98: averaged train_err_rate: 11.112500% averaged train nll: 0.333819 averaged train loss: 0.816257
# At minibatch 157200, batch loss 0.645258, batch nll 0.162583, batch error rate 4.000000%
# At minibatch 157600, batch loss 0.749306, batch nll 0.266584, batch error rate 8.000000%
# At minibatch 158000, batch loss 0.656519, batch nll 0.173528, batch error rate 4.000000%
# At minibatch 158400, batch loss 0.724452, batch nll 0.241329, batch error rate 4.000000%
# After epoch 99: valid_err_rate: 18.130000% currently going to do 146 epochs
# After epoch 99: averaged train_err_rate: 11.192500% averaged train nll: 0.333433 averaged train loss: 0.816203
# At minibatch 158800, batch loss 0.862536, batch nll 0.378920, batch error rate 4.000000%
# At minibatch 159200, batch loss 0.803841, batch nll 0.320071, batch error rate 4.000000%
# At minibatch 159600, batch loss 0.763790, batch nll 0.279675, batch error rate 8.000000%
# At minibatch 160000, batch loss 1.016012, batch nll 0.532290, batch error rate 12.000000%
# After epoch 100: valid_err_rate: 17.760000% currently going to do 146 epochs
# After epoch 100: averaged train_err_rate: 10.545000% averaged train nll: 0.321224 averaged train loss: 0.804992
# At minibatch 160400, batch loss 0.733840, batch nll 0.250019, batch error rate 12.000000%
# At minibatch 160800, batch loss 0.833799, batch nll 0.349541, batch error rate 12.000000%
# At minibatch 161200, batch loss 1.005236, batch nll 0.521184, batch error rate 20.000000%
# At minibatch 161600, batch loss 0.901651, batch nll 0.417528, batch error rate 16.000000%
# After epoch 101: valid_err_rate: 18.170000% currently going to do 146 epochs
# After epoch 101: averaged train_err_rate: 10.842500% averaged train nll: 0.326256 averaged train loss: 0.810353
# At minibatch 162000, batch loss 0.982318, batch nll 0.497895, batch error rate 20.000000%
# At minibatch 162400, batch loss 0.764444, batch nll 0.280049, batch error rate 4.000000%
# At minibatch 162800, batch loss 1.058401, batch nll 0.573872, batch error rate 16.000000%
# At minibatch 163200, batch loss 0.816920, batch nll 0.332821, batch error rate 12.000000%
# After epoch 102: valid_err_rate: 18.710000% currently going to do 146 epochs
# After epoch 102: averaged train_err_rate: 10.722500% averaged train nll: 0.325816 averaged train loss: 0.810192
# At minibatch 163600, batch loss 0.818980, batch nll 0.334294, batch error rate 8.000000%
# At minibatch 164000, batch loss 0.725497, batch nll 0.240654, batch error rate 8.000000%
# At minibatch 164400, batch loss 0.667781, batch nll 0.182907, batch error rate 8.000000%
# At minibatch 164800, batch loss 0.928518, batch nll 0.443635, batch error rate 16.000000%
# After epoch 103: valid_err_rate: 17.830000% currently going to do 146 epochs
# After epoch 103: averaged train_err_rate: 10.617500% averaged train nll: 0.321854 averaged train loss: 0.806567
# At minibatch 165200, batch loss 0.923970, batch nll 0.439020, batch error rate 20.000000%
# At minibatch 165600, batch loss 0.789098, batch nll 0.303984, batch error rate 12.000000%
# At minibatch 166000, batch loss 0.974879, batch nll 0.489910, batch error rate 24.000000%
# At minibatch 166400, batch loss 0.768506, batch nll 0.283248, batch error rate 4.000000%
# After epoch 104: valid_err_rate: 18.060000% currently going to do 146 epochs
# After epoch 104: averaged train_err_rate: 10.827500% averaged train nll: 0.323378 averaged train loss: 0.808455
# At minibatch 166800, batch loss 0.709264, batch nll 0.223725, batch error rate 8.000000%
# At minibatch 167200, batch loss 0.596862, batch nll 0.110982, batch error rate 4.000000%
# At minibatch 167600, batch loss 0.777700, batch nll 0.291838, batch error rate 4.000000%
# At minibatch 168000, batch loss 0.735663, batch nll 0.249574, batch error rate 8.000000%
# After epoch 105: valid_err_rate: 17.820000% currently going to do 146 epochs
# After epoch 105: averaged train_err_rate: 10.600000% averaged train nll: 0.318303 averaged train loss: 0.804032
# At minibatch 168400, batch loss 0.773839, batch nll 0.287538, batch error rate 8.000000%
# At minibatch 168800, batch loss 0.654640, batch nll 0.167930, batch error rate 4.000000%
# At minibatch 169200, batch loss 0.991957, batch nll 0.505184, batch error rate 20.000000%
# At minibatch 169600, batch loss 0.609001, batch nll 0.122523, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 17.210000% currently going to do 160 epochs
# After epoch 106: averaged train_err_rate: 10.402500% averaged train nll: 0.312785 averaged train loss: 0.799308
# At minibatch 170000, batch loss 1.173406, batch nll 0.686509, batch error rate 28.000000%
# At minibatch 170400, batch loss 0.886600, batch nll 0.399835, batch error rate 16.000000%
# At minibatch 170800, batch loss 0.745549, batch nll 0.258374, batch error rate 16.000000%
# At minibatch 171200, batch loss 0.915256, batch nll 0.428562, batch error rate 12.000000%
# After epoch 107: valid_err_rate: 18.410000% currently going to do 160 epochs
# After epoch 107: averaged train_err_rate: 10.542500% averaged train nll: 0.317741 averaged train loss: 0.804618
# At minibatch 171600, batch loss 0.723166, batch nll 0.235883, batch error rate 8.000000%
# At minibatch 172000, batch loss 1.028690, batch nll 0.541316, batch error rate 24.000000%
# At minibatch 172400, batch loss 0.831072, batch nll 0.343781, batch error rate 12.000000%
# At minibatch 172800, batch loss 0.859058, batch nll 0.371851, batch error rate 12.000000%
# After epoch 108: valid_err_rate: 17.580000% currently going to do 160 epochs
# After epoch 108: averaged train_err_rate: 10.140000% averaged train nll: 0.309956 averaged train loss: 0.797214
# At minibatch 173200, batch loss 0.725885, batch nll 0.238391, batch error rate 4.000000%
# At minibatch 173600, batch loss 0.644246, batch nll 0.156368, batch error rate 0.000000%
# At minibatch 174000, batch loss 0.736870, batch nll 0.248876, batch error rate 8.000000%
# At minibatch 174400, batch loss 0.643968, batch nll 0.156131, batch error rate 4.000000%
# After epoch 109: valid_err_rate: 18.690000% currently going to do 160 epochs
# After epoch 109: averaged train_err_rate: 10.365000% averaged train nll: 0.312305 averaged train loss: 0.800053
# At minibatch 174800, batch loss 0.734235, batch nll 0.246381, batch error rate 8.000000%
# At minibatch 175200, batch loss 1.052799, batch nll 0.564572, batch error rate 20.000000%
# At minibatch 175600, batch loss 0.740858, batch nll 0.252670, batch error rate 12.000000%
# At minibatch 176000, batch loss 0.734160, batch nll 0.245980, batch error rate 8.000000%
# After epoch 110: valid_err_rate: 17.860000% currently going to do 160 epochs
# After epoch 110: averaged train_err_rate: 10.200000% averaged train nll: 0.307389 averaged train loss: 0.795440
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bd641399dfa9> in <module>()
#      12         momentum=0.9
#      13
# ---> 14         L, err_rate, nll, wdec = train_step(shake(X_batch), Y_batch, lrate, momentum)
#      15
#      16         train_loss.append((i,L))
#
# /pio/os/anaconda/lib/python2.7/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# /pio/os/anaconda/lib/python2.7/site-packages/theano/gof/op.py in rval(p, i, o, n)
#     765         if ctx is graph.NoContext:
#     766             # default arguments are stored in the closure of `rval`
# --> 767             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     768                 r = p(n, [x[0] for x in i], o)
#     769                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Test error rate is %f%%" %(compute_error_rate(cifar_test_stream)*100.0,)

figure(figsize(12,6))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
train_erros_av = zeros(train_erros_a.shape[0])
for i in range(train_erros_a.shape[0]):
    train_erros_av[i] = mean(train_erros_a[max(0,i-1000):i+1,1])
plot(train_erros_a[:,0], train_erros_av, label='batch train error rate (smoothed)')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate', color='r')
ylim(0,1.)
legend()
show()
# Out:
# Setting network parameters from after epoch 106
# Test error rate is 17.760000%

# %%
test_Y = array([], dtype=int)
predicted_Y = array([], dtype=int)

for X, Y in cifar_test_stream.get_epoch_iterator():
        pred = predict(X).ravel()
        predicted_Y = append(predicted_Y, predict(X).ravel())
        
        test_Y = append(test_Y, Y.ravel())

# %%
# save best params to file

import pickle

pickle.dump( best_params, open( "best_params.p", "wb" ) )

# best_params = pickle.load( open( "best_params.p", "rb" ) )

# %%
# save test results to file

with open('test_results.txt', 'w') as f:
    for i in range(test_Y.shape[0]):
        f.write("%d %d\n" % (predicted_Y[i], test_Y[i]))

# %% [markdown]
# Examples of incorrectly predicted pictures

# %%
from common.plotting import plot_mat

# %%
label_names = "airplane automobile bird cat deer dog frog horse ship truck".split(" ")

wrong_labels = []

for i in range(10000):
    if test_Y[i] != predicted_Y[i]:
        wrong_labels.append(i)

#print wrong_labels

figure(figsize = (14,14))
r, c = 5, 5
for i in range(r):
    for j in range(c):
        no = c*i + j
        subplot(r, c, no+1)
        idx = wrong_labels[no]
        plot_mat(cifar_test.data_sources[0][idx:idx+1], cmap='gray')
        title("%s predicted as %s" % (label_names[test_Y[idx]], label_names[predicted_Y[idx]]))
show()

# %%
#How do the filters in the first layer look like?

plot_mat(CW1.get_value(), cmap='gray')

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=4

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
