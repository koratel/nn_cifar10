# %% [markdown]
# # CIFAR10 classification with convolutional neural network

# %% [markdown]
# Michał Łowicki, 258350

# %% [markdown]
# Code adapted from the [MNIST convolutions example](https://sites.google.com/a/cs.uni.wroc.pl/jch/teaching/neuralnetworks15/materialsforlectures710/10-convolutions.ipynb).

# %% [markdown]
# ###Test data accuracy: 82.18%

# %% [markdown]
# ### Architecture
#
# This neural network consists of the following layers:
#
# 1. Convolution with 50 5x5 filters
# 2. 2x2 maxpool
# 3. Convolution with 100 5x5 filters
# 4. 2x2 maxpool
# 5. Fully connected with 500 neurons
# 6. ReLU
# 7. Fully connected with 500 neurons
# 8. ReLU
# 9. Fully connected with 100 neurons
# 10. ReLU
# 11. Fully connected with 10 neurons
# 12. SoftMax

# %% [markdown]
# ### Main improvement - generating synthetic data
#
# To lower variance the training input is "shaken" - each picture from the batch is randomly rolled by -4 to 4 pixels up and down independently (elements that roll beyond the last position are re-introduced at the beginning). This artificially increases the training set size 64 times and decreases the network's ability to over-fit - it can no longer easily achieve >99% accuracy on training data. In result the test data accuracy significantly improved from 75.43% to 82.18%.
#
# The downside is increased training time (around 4 times longer), but the improvement in accuracy fully justifies that.

# %%
# %pylab inline

import theano
import theano.tensor.signal.downsample
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 28 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 28 days
# Using gpu device 0: GeForce GTX 780
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Data streams

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the CIFAR set and return us batches of 25 examples
cifar_train_stream = DataStream.default_stream(
    cifar_train,
    iteration_scheme=ShuffledScheme(cifar_train.num_examples, 25))
                                               
cifar_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar_validation_stream = DataStream.default_stream(
    cifar_validation, iteration_scheme=SequentialScheme(cifar_validation.num_examples, 100))
cifar_test = CIFAR10(("test",))
cifar_test_stream = DataStream.default_stream(
    cifar_test, iteration_scheme=SequentialScheme(cifar_test.num_examples, 100))

# %%
print "The streams return batches containing %s" % (cifar_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'raise' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 50 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'),
                   name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'),
                    name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x')
    )
# print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
# print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 100 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'),
                   name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'),
                    name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x')
    )
# print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
# print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=500
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'),
                   name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)

FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'),
                    name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
# print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)

num_fw3a_hidden=500
FW3a = theano.shared(np.zeros((num_fw3_hidden, num_fw3a_hidden), dtype='float32'),
                   name='FW3a')
FW3a.tag.initializer = IsotropicGaussian(0.05)

FB3a = theano.shared(np.zeros((num_fw3a_hidden,), dtype='float32'),
                    name='FB3a')
FB3a.tag.initializer = Constant(0.0)
model_parameters += [FW3a, FB3a]

after_F3a = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3, FW3a) + FB3a.dimshuffle('x',0))
# print "after_F3a shape: %s" % (after_F3a.tag.test_value.shape,)

num_fw3b_hidden=100
FW3b = theano.shared(np.zeros((num_fw3a_hidden, num_fw3b_hidden), dtype='float32'),
                   name='FW3b')
FW3b.tag.initializer = IsotropicGaussian(0.05)

FB3b = theano.shared(np.zeros((num_fw3b_hidden,), dtype='float32'),
                    name='FB3b')
FB3b.tag.initializer = Constant(0.0)
model_parameters += [FW3b, FB3b]

after_F3b = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3a, FW3b) + FB3b.dimshuffle('x',0))
# print "after_F3b shape: %s" % (after_F3b.tag.test_value.shape,)

num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw3b_hidden, num_fw4_hidden), dtype='float32'),
                   name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'),
                    name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F3b, FW4) + FB4.dimshuffle('x',0)
# print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 2e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)

# %%
#
# We have built a computation graph for computing the error_rate, predictions and cost
#
#svgdotprint(nll)

# %%
# The updates will update our shared values
updates = []

# %%
lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW3a, Elemwise{sub,no_inplace}.0),
#  (FW3a, Elemwise{add,no_inplace}.0),
#  (V_FB3a, Elemwise{sub,no_inplace}.0),
#  (FB3a, Elemwise{add,no_inplace}.0),
#  (V_FW3b, Elemwise{sub,no_inplace}.0),
#  (FW3b, Elemwise{add,no_inplace}.0),
#  (V_FB3b, Elemwise{sub,no_inplace}.0),
#  (FB3b, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

# %%
#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
def shake(X_batch):
    ret = X_batch
    for i in range(ret.shape[0]):
        ret[i] = roll(ret[i],randint(-4,5),axis=1)
        ret[i] = roll(ret[i],randint(-4,5),axis=2)
    return ret

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# %%
# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 5000
        lrate = 2e-2 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(shake(X_batch), Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 100, batch loss 9.421534, batch nll 2.132739, batch error rate 84.000000%
# At minibatch 200, batch loss 7.933913, batch nll 1.705247, batch error rate 64.000000%
# At minibatch 300, batch loss 7.298665, batch nll 1.972360, batch error rate 68.000000%
# At minibatch 400, batch loss 6.685806, batch nll 2.126504, batch error rate 84.000000%
# At minibatch 500, batch loss 5.459399, batch nll 1.552925, batch error rate 60.000000%
# At minibatch 600, batch loss 5.103511, batch nll 1.748546, batch error rate 68.000000%
# At minibatch 700, batch loss 4.778277, batch nll 1.893851, batch error rate 64.000000%
# At minibatch 800, batch loss 4.087170, batch nll 1.602781, batch error rate 72.000000%
# At minibatch 900, batch loss 4.474967, batch nll 2.330981, batch error rate 84.000000%
# At minibatch 1000, batch loss 3.632449, batch nll 1.773396, batch error rate 56.000000%
# At minibatch 1100, batch loss 3.535310, batch nll 1.920964, batch error rate 76.000000%
# At minibatch 1200, batch loss 3.293769, batch nll 1.884485, batch error rate 76.000000%
# At minibatch 1300, batch loss 3.319397, batch nll 2.084471, batch error rate 68.000000%
# At minibatch 1400, batch loss 2.405276, batch nll 1.320095, batch error rate 48.000000%
# At minibatch 1500, batch loss 2.846450, batch nll 1.887012, batch error rate 68.000000%
# At minibatch 1600, batch loss 2.264937, batch nll 1.407344, batch error rate 60.000000%
# After epoch 1: valid_err_rate: 51.720000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 64.942500% averaged train nll: 1.739000 averaged train loss: 4.919359
# At minibatch 1700, batch loss 2.198643, batch nll 1.431872, batch error rate 56.000000%
# At minibatch 1800, batch loss 2.050974, batch nll 1.357523, batch error rate 48.000000%
# At minibatch 1900, batch loss 2.420679, batch nll 1.792351, batch error rate 60.000000%
# At minibatch 2000, batch loss 2.329129, batch nll 1.751096, batch error rate 48.000000%
# At minibatch 2100, batch loss 1.994334, batch nll 1.461830, batch error rate 48.000000%
# At minibatch 2200, batch loss 2.268662, batch nll 1.772658, batch error rate 64.000000%
# At minibatch 2300, batch loss 2.148605, batch nll 1.686811, batch error rate 76.000000%
# At minibatch 2400, batch loss 1.860553, batch nll 1.425766, batch error rate 48.000000%
# At minibatch 2500, batch loss 1.740672, batch nll 1.323096, batch error rate 56.000000%
# At minibatch 2600, batch loss 1.991188, batch nll 1.595051, batch error rate 56.000000%
# At minibatch 2700, batch loss 1.590719, batch nll 1.206653, batch error rate 44.000000%
# At minibatch 2800, batch loss 1.593116, batch nll 1.222731, batch error rate 40.000000%
# At minibatch 2900, batch loss 1.820494, batch nll 1.462377, batch error rate 48.000000%
# At minibatch 3000, batch loss 1.711298, batch nll 1.361211, batch error rate 52.000000%
# At minibatch 3100, batch loss 1.733106, batch nll 1.382571, batch error rate 40.000000%
# At minibatch 3200, batch loss 1.778271, batch nll 1.433637, batch error rate 64.000000%
# After epoch 2: valid_err_rate: 50.620000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 54.505000% averaged train nll: 1.513626 averaged train loss: 2.002164
# At minibatch 3300, batch loss 1.540092, batch nll 1.195099, batch error rate 40.000000%
# At minibatch 3400, batch loss 2.269748, batch nll 1.925379, batch error rate 68.000000%
# At minibatch 3500, batch loss 1.366747, batch nll 1.023028, batch error rate 36.000000%
# At minibatch 3600, batch loss 2.032326, batch nll 1.690975, batch error rate 64.000000%
# At minibatch 3700, batch loss 1.883669, batch nll 1.543697, batch error rate 68.000000%
# At minibatch 3800, batch loss 1.715623, batch nll 1.373039, batch error rate 56.000000%
# At minibatch 3900, batch loss 1.732853, batch nll 1.387941, batch error rate 60.000000%
# At minibatch 4000, batch loss 1.583207, batch nll 1.239091, batch error rate 52.000000%
# At minibatch 4100, batch loss 1.752262, batch nll 1.409130, batch error rate 48.000000%
# At minibatch 4200, batch loss 1.727652, batch nll 1.382935, batch error rate 44.000000%
# At minibatch 4300, batch loss 2.218909, batch nll 1.872162, batch error rate 64.000000%
# At minibatch 4400, batch loss 1.871563, batch nll 1.522440, batch error rate 48.000000%
# At minibatch 4500, batch loss 1.738100, batch nll 1.389439, batch error rate 52.000000%
# At minibatch 4600, batch loss 1.593945, batch nll 1.242993, batch error rate 40.000000%
# At minibatch 4700, batch loss 1.673458, batch nll 1.320452, batch error rate 48.000000%
# At minibatch 4800, batch loss 1.926601, batch nll 1.569617, batch error rate 56.000000%
# After epoch 3: valid_err_rate: 46.500000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 50.695000% averaged train nll: 1.422685 averaged train loss: 1.768246
# At minibatch 4900, batch loss 1.802043, batch nll 1.439678, batch error rate 48.000000%
# At minibatch 5000, batch loss 1.577015, batch nll 1.211375, batch error rate 44.000000%
# At minibatch 5100, batch loss 1.293066, batch nll 0.923574, batch error rate 32.000000%
# At minibatch 5200, batch loss 2.072639, batch nll 1.701537, batch error rate 56.000000%
# At minibatch 5300, batch loss 1.447449, batch nll 1.078978, batch error rate 40.000000%
# At minibatch 5400, batch loss 1.667711, batch nll 1.301076, batch error rate 44.000000%
# At minibatch 5500, batch loss 1.843623, batch nll 1.469909, batch error rate 44.000000%
# At minibatch 5600, batch loss 1.692719, batch nll 1.320085, batch error rate 40.000000%
# At minibatch 5700, batch loss 1.545413, batch nll 1.168683, batch error rate 36.000000%
# At minibatch 5800, batch loss 1.712048, batch nll 1.335142, batch error rate 52.000000%
# At minibatch 5900, batch loss 2.052911, batch nll 1.677441, batch error rate 64.000000%
# At minibatch 6000, batch loss 2.047580, batch nll 1.669007, batch error rate 52.000000%
# At minibatch 6100, batch loss 1.620322, batch nll 1.242184, batch error rate 56.000000%
# At minibatch 6200, batch loss 1.444738, batch nll 1.070644, batch error rate 52.000000%
# At minibatch 6300, batch loss 1.829834, batch nll 1.454758, batch error rate 48.000000%
# At minibatch 6400, batch loss 1.466808, batch nll 1.092768, batch error rate 40.000000%
# After epoch 4: valid_err_rate: 39.290000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 47.202500% averaged train nll: 1.337920 averaged train loss: 1.709564
# At minibatch 6500, batch loss 1.768245, batch nll 1.394818, batch error rate 56.000000%
# At minibatch 6600, batch loss 0.992796, batch nll 0.615487, batch error rate 16.000000%
# At minibatch 6700, batch loss 1.556138, batch nll 1.178807, batch error rate 48.000000%
# At minibatch 6800, batch loss 1.701168, batch nll 1.324261, batch error rate 52.000000%
# At minibatch 6900, batch loss 1.381379, batch nll 1.006045, batch error rate 40.000000%
# At minibatch 7000, batch loss 1.294790, batch nll 0.918919, batch error rate 28.000000%
# At minibatch 7100, batch loss 1.412423, batch nll 1.034830, batch error rate 44.000000%
# At minibatch 7200, batch loss 1.458710, batch nll 1.081107, batch error rate 36.000000%
# At minibatch 7300, batch loss 1.666861, batch nll 1.286164, batch error rate 44.000000%
# At minibatch 7400, batch loss 1.398738, batch nll 1.017909, batch error rate 36.000000%
# At minibatch 7500, batch loss 1.680467, batch nll 1.296854, batch error rate 52.000000%
# At minibatch 7600, batch loss 1.923567, batch nll 1.540649, batch error rate 52.000000%
# At minibatch 7700, batch loss 1.481295, batch nll 1.100182, batch error rate 36.000000%
# At minibatch 7800, batch loss 1.758285, batch nll 1.379346, batch error rate 44.000000%
# At minibatch 7900, batch loss 1.599544, batch nll 1.220657, batch error rate 52.000000%
# At minibatch 8000, batch loss 2.235573, batch nll 1.857408, batch error rate 64.000000%
# After epoch 5: valid_err_rate: 41.040000% currently going to do 7 epochs
# After epoch 5: averaged train_err_rate: 43.352500% averaged train nll: 1.229330 averaged train loss: 1.607898
# At minibatch 8100, batch loss 1.439652, batch nll 1.060191, batch error rate 40.000000%
# At minibatch 8200, batch loss 1.347699, batch nll 0.966533, batch error rate 36.000000%
# At minibatch 8300, batch loss 1.710526, batch nll 1.330505, batch error rate 44.000000%
# At minibatch 8400, batch loss 1.450331, batch nll 1.071923, batch error rate 40.000000%
# At minibatch 8500, batch loss 1.778735, batch nll 1.391937, batch error rate 40.000000%
# At minibatch 8600, batch loss 1.713201, batch nll 1.327023, batch error rate 44.000000%
# At minibatch 8700, batch loss 1.644581, batch nll 1.258579, batch error rate 40.000000%
# At minibatch 8800, batch loss 1.464302, batch nll 1.080192, batch error rate 36.000000%
# At minibatch 8900, batch loss 1.520409, batch nll 1.135626, batch error rate 36.000000%
# At minibatch 9000, batch loss 2.010341, batch nll 1.624683, batch error rate 48.000000%
# At minibatch 9100, batch loss 1.324835, batch nll 0.942513, batch error rate 44.000000%
# At minibatch 9200, batch loss 1.544471, batch nll 1.159224, batch error rate 48.000000%
# At minibatch 9300, batch loss 1.510786, batch nll 1.128844, batch error rate 44.000000%
# At minibatch 9400, batch loss 1.512035, batch nll 1.129829, batch error rate 44.000000%
# At minibatch 9500, batch loss 1.440494, batch nll 1.058808, batch error rate 40.000000%
# At minibatch 9600, batch loss 1.332148, batch nll 0.948037, batch error rate 36.000000%
# After epoch 6: valid_err_rate: 34.700000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 40.330000% averaged train nll: 1.140807 averaged train loss: 1.523903
# At minibatch 9700, batch loss 1.296827, batch nll 0.912476, batch error rate 36.000000%
# At minibatch 9800, batch loss 1.525711, batch nll 1.140446, batch error rate 44.000000%
# At minibatch 9900, batch loss 1.575269, batch nll 1.188936, batch error rate 40.000000%
# At minibatch 10000, batch loss 1.371447, batch nll 0.984443, batch error rate 36.000000%
# At minibatch 10100, batch loss 1.499152, batch nll 1.110365, batch error rate 40.000000%
# At minibatch 10200, batch loss 1.567896, batch nll 1.178565, batch error rate 32.000000%
# At minibatch 10300, batch loss 1.201463, batch nll 0.815781, batch error rate 28.000000%
# At minibatch 10400, batch loss 1.683813, batch nll 1.296506, batch error rate 48.000000%
# At minibatch 10500, batch loss 1.490477, batch nll 1.102895, batch error rate 40.000000%
# At minibatch 10600, batch loss 1.597611, batch nll 1.208705, batch error rate 40.000000%
# At minibatch 10700, batch loss 1.581598, batch nll 1.195902, batch error rate 32.000000%
# At minibatch 10800, batch loss 1.574457, batch nll 1.188835, batch error rate 40.000000%
# At minibatch 10900, batch loss 1.128608, batch nll 0.742949, batch error rate 32.000000%
# At minibatch 11000, batch loss 1.685954, batch nll 1.302637, batch error rate 48.000000%
# At minibatch 11100, batch loss 1.309566, batch nll 0.927774, batch error rate 36.000000%
# At minibatch 11200, batch loss 1.645809, batch nll 1.261541, batch error rate 48.000000%
# After epoch 7: valid_err_rate: 34.710000% currently going to do 10 epochs
# After epoch 7: averaged train_err_rate: 38.117500% averaged train nll: 1.079173 averaged train loss: 1.465391
# At minibatch 11300, batch loss 1.374680, batch nll 0.989160, batch error rate 40.000000%
# At minibatch 11400, batch loss 1.416791, batch nll 1.027761, batch error rate 40.000000%
# At minibatch 11500, batch loss 1.330987, batch nll 0.939129, batch error rate 36.000000%
# At minibatch 11600, batch loss 1.156863, batch nll 0.765119, batch error rate 36.000000%
# At minibatch 11700, batch loss 1.467349, batch nll 1.078116, batch error rate 48.000000%
# At minibatch 11800, batch loss 1.349011, batch nll 0.959770, batch error rate 32.000000%
# At minibatch 11900, batch loss 1.384649, batch nll 0.996720, batch error rate 36.000000%
# At minibatch 12000, batch loss 1.593498, batch nll 1.206066, batch error rate 52.000000%
# At minibatch 12100, batch loss 1.261299, batch nll 0.873565, batch error rate 28.000000%
# At minibatch 12200, batch loss 1.386289, batch nll 0.998320, batch error rate 28.000000%
# At minibatch 12300, batch loss 1.993548, batch nll 1.602853, batch error rate 56.000000%
# At minibatch 12400, batch loss 1.036253, batch nll 0.646951, batch error rate 24.000000%
# At minibatch 12500, batch loss 1.276565, batch nll 0.887355, batch error rate 32.000000%
# At minibatch 12600, batch loss 1.390992, batch nll 1.003129, batch error rate 32.000000%
# At minibatch 12700, batch loss 1.560066, batch nll 1.173471, batch error rate 40.000000%
# At minibatch 12800, batch loss 2.105245, batch nll 1.717365, batch error rate 56.000000%
# After epoch 8: valid_err_rate: 32.060000% currently going to do 13 epochs
# After epoch 8: averaged train_err_rate: 35.937500% averaged train nll: 1.023667 averaged train loss: 1.412435
# At minibatch 12900, batch loss 1.519826, batch nll 1.132204, batch error rate 52.000000%
# At minibatch 13000, batch loss 1.336936, batch nll 0.948804, batch error rate 36.000000%
# At minibatch 13100, batch loss 1.541285, batch nll 1.152558, batch error rate 32.000000%
# At minibatch 13200, batch loss 1.104556, batch nll 0.713935, batch error rate 28.000000%
# At minibatch 13300, batch loss 1.167706, batch nll 0.776174, batch error rate 24.000000%
# At minibatch 13400, batch loss 1.214073, batch nll 0.823288, batch error rate 28.000000%
# At minibatch 13500, batch loss 1.438940, batch nll 1.047078, batch error rate 40.000000%
# At minibatch 13600, batch loss 1.629371, batch nll 1.237892, batch error rate 48.000000%
# At minibatch 13700, batch loss 1.656287, batch nll 1.265276, batch error rate 44.000000%
# At minibatch 13800, batch loss 1.308658, batch nll 0.917562, batch error rate 28.000000%
# At minibatch 13900, batch loss 1.790779, batch nll 1.399294, batch error rate 40.000000%
# At minibatch 14000, batch loss 1.090596, batch nll 0.699201, batch error rate 24.000000%
# At minibatch 14100, batch loss 1.355362, batch nll 0.965525, batch error rate 40.000000%
# At minibatch 14200, batch loss 1.633780, batch nll 1.243890, batch error rate 40.000000%
# At minibatch 14300, batch loss 1.040399, batch nll 0.651346, batch error rate 24.000000%
# At minibatch 14400, batch loss 1.104711, batch nll 0.715952, batch error rate 20.000000%
# After epoch 9: valid_err_rate: 30.330000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 34.417500% averaged train nll: 0.979797 averaged train loss: 1.369821
# At minibatch 14500, batch loss 1.363023, batch nll 0.975222, batch error rate 28.000000%
# At minibatch 14600, batch loss 1.392012, batch nll 1.002321, batch error rate 32.000000%
# At minibatch 14700, batch loss 1.232142, batch nll 0.842212, batch error rate 32.000000%
# At minibatch 14800, batch loss 1.580785, batch nll 1.190042, batch error rate 48.000000%
# At minibatch 14900, batch loss 1.383919, batch nll 0.994131, batch error rate 40.000000%
# At minibatch 15000, batch loss 1.107650, batch nll 0.717214, batch error rate 20.000000%
# At minibatch 15100, batch loss 1.471818, batch nll 1.082147, batch error rate 44.000000%
# At minibatch 15200, batch loss 1.382174, batch nll 0.991775, batch error rate 44.000000%
# At minibatch 15300, batch loss 1.322062, batch nll 0.931766, batch error rate 32.000000%
# At minibatch 15400, batch loss 1.475353, batch nll 1.084612, batch error rate 40.000000%
# At minibatch 15500, batch loss 1.704103, batch nll 1.314039, batch error rate 44.000000%
# At minibatch 15600, batch loss 1.050239, batch nll 0.659580, batch error rate 24.000000%
# At minibatch 15700, batch loss 1.314433, batch nll 0.923841, batch error rate 32.000000%
# At minibatch 15800, batch loss 1.138214, batch nll 0.746257, batch error rate 28.000000%
# At minibatch 15900, batch loss 1.405880, batch nll 1.012998, batch error rate 40.000000%
# At minibatch 16000, batch loss 1.313623, batch nll 0.920623, batch error rate 24.000000%
# After epoch 10: valid_err_rate: 31.000000% currently going to do 14 epochs
# After epoch 10: averaged train_err_rate: 33.095000% averaged train nll: 0.941418 averaged train loss: 1.332113
# At minibatch 16100, batch loss 1.463381, batch nll 1.070581, batch error rate 40.000000%
# At minibatch 16200, batch loss 1.539542, batch nll 1.144948, batch error rate 36.000000%
# At minibatch 16300, batch loss 1.187289, batch nll 0.793556, batch error rate 24.000000%
# At minibatch 16400, batch loss 0.964683, batch nll 0.570638, batch error rate 20.000000%
# At minibatch 16500, batch loss 1.233031, batch nll 0.839251, batch error rate 32.000000%
# At minibatch 16600, batch loss 1.378458, batch nll 0.984872, batch error rate 24.000000%
# At minibatch 16700, batch loss 1.686116, batch nll 1.292895, batch error rate 32.000000%
# At minibatch 16800, batch loss 1.254020, batch nll 0.859717, batch error rate 28.000000%
# At minibatch 16900, batch loss 0.991388, batch nll 0.596597, batch error rate 20.000000%
# At minibatch 17000, batch loss 1.389355, batch nll 0.993533, batch error rate 36.000000%
# At minibatch 17100, batch loss 1.097550, batch nll 0.703989, batch error rate 28.000000%
# At minibatch 17200, batch loss 1.299654, batch nll 0.905423, batch error rate 32.000000%
# At minibatch 17300, batch loss 1.358664, batch nll 0.964251, batch error rate 32.000000%
# At minibatch 17400, batch loss 1.494223, batch nll 1.101629, batch error rate 36.000000%
# At minibatch 17500, batch loss 1.201702, batch nll 0.809422, batch error rate 24.000000%
# At minibatch 17600, batch loss 1.010888, batch nll 0.618788, batch error rate 24.000000%
# After epoch 11: valid_err_rate: 28.950000% currently going to do 17 epochs
# After epoch 11: averaged train_err_rate: 32.005000% averaged train nll: 0.912917 averaged train loss: 1.306635
# At minibatch 17700, batch loss 1.392810, batch nll 0.999484, batch error rate 36.000000%
# At minibatch 17800, batch loss 1.498320, batch nll 1.104685, batch error rate 48.000000%
# At minibatch 17900, batch loss 1.576621, batch nll 1.181174, batch error rate 40.000000%
# At minibatch 18000, batch loss 1.311945, batch nll 0.916709, batch error rate 40.000000%
# At minibatch 18100, batch loss 1.608115, batch nll 1.214918, batch error rate 48.000000%
# At minibatch 18200, batch loss 1.330489, batch nll 0.935047, batch error rate 44.000000%
# At minibatch 18300, batch loss 1.555272, batch nll 1.159665, batch error rate 36.000000%
# At minibatch 18400, batch loss 1.158604, batch nll 0.762199, batch error rate 24.000000%
# At minibatch 18500, batch loss 1.128809, batch nll 0.731954, batch error rate 16.000000%
# At minibatch 18600, batch loss 1.355556, batch nll 0.959528, batch error rate 36.000000%
# At minibatch 18700, batch loss 1.222016, batch nll 0.827784, batch error rate 24.000000%
# At minibatch 18800, batch loss 1.302607, batch nll 0.906804, batch error rate 28.000000%
# At minibatch 18900, batch loss 1.433948, batch nll 1.037601, batch error rate 32.000000%
# At minibatch 19000, batch loss 1.347051, batch nll 0.952152, batch error rate 48.000000%
# At minibatch 19100, batch loss 1.249695, batch nll 0.853538, batch error rate 28.000000%
# At minibatch 19200, batch loss 1.344968, batch nll 0.950020, batch error rate 32.000000%
# After epoch 12: valid_err_rate: 28.870000% currently going to do 19 epochs
# After epoch 12: averaged train_err_rate: 30.875000% averaged train nll: 0.880197 averaged train loss: 1.275447
# At minibatch 19300, batch loss 1.235910, batch nll 0.839117, batch error rate 36.000000%
# At minibatch 19400, batch loss 1.004101, batch nll 0.608089, batch error rate 20.000000%
# At minibatch 19500, batch loss 1.203145, batch nll 0.805788, batch error rate 36.000000%
# At minibatch 19600, batch loss 1.269237, batch nll 0.870430, batch error rate 32.000000%
# At minibatch 19700, batch loss 1.085408, batch nll 0.687169, batch error rate 32.000000%
# At minibatch 19800, batch loss 0.937122, batch nll 0.538407, batch error rate 20.000000%
# At minibatch 19900, batch loss 1.188245, batch nll 0.790551, batch error rate 36.000000%
# At minibatch 20000, batch loss 0.979851, batch nll 0.583110, batch error rate 20.000000%
# At minibatch 20100, batch loss 1.372563, batch nll 0.977545, batch error rate 40.000000%
# At minibatch 20200, batch loss 1.301212, batch nll 0.905486, batch error rate 28.000000%
# At minibatch 20300, batch loss 1.152823, batch nll 0.757696, batch error rate 24.000000%
# At minibatch 20400, batch loss 1.165054, batch nll 0.770519, batch error rate 36.000000%
# At minibatch 20500, batch loss 1.401840, batch nll 1.006033, batch error rate 40.000000%
# At minibatch 20600, batch loss 1.354101, batch nll 0.958735, batch error rate 28.000000%
# At minibatch 20700, batch loss 0.969667, batch nll 0.573726, batch error rate 24.000000%
# At minibatch 20800, batch loss 0.984303, batch nll 0.588286, batch error rate 16.000000%
# After epoch 13: valid_err_rate: 28.380000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 29.907500% averaged train nll: 0.851708 averaged train loss: 1.248188
# At minibatch 20900, batch loss 1.423365, batch nll 1.026248, batch error rate 36.000000%
# At minibatch 21000, batch loss 1.211720, batch nll 0.814313, batch error rate 28.000000%
# At minibatch 21100, batch loss 0.986807, batch nll 0.589207, batch error rate 16.000000%
# At minibatch 21200, batch loss 1.035139, batch nll 0.636584, batch error rate 28.000000%
# At minibatch 21300, batch loss 1.410684, batch nll 1.011296, batch error rate 32.000000%
# At minibatch 21400, batch loss 1.241053, batch nll 0.841066, batch error rate 28.000000%
# At minibatch 21500, batch loss 1.178977, batch nll 0.779202, batch error rate 28.000000%
# At minibatch 21600, batch loss 0.911461, batch nll 0.512161, batch error rate 20.000000%
# At minibatch 21700, batch loss 1.005431, batch nll 0.606888, batch error rate 16.000000%
# At minibatch 21800, batch loss 1.509338, batch nll 1.110922, batch error rate 48.000000%
# At minibatch 21900, batch loss 1.092197, batch nll 0.694173, batch error rate 20.000000%
# At minibatch 22000, batch loss 1.469625, batch nll 1.070142, batch error rate 36.000000%
# At minibatch 22100, batch loss 1.359806, batch nll 0.959590, batch error rate 44.000000%
# At minibatch 22200, batch loss 1.123447, batch nll 0.724316, batch error rate 32.000000%
# At minibatch 22300, batch loss 1.051334, batch nll 0.653637, batch error rate 24.000000%
# At minibatch 22400, batch loss 0.972066, batch nll 0.572956, batch error rate 20.000000%
# After epoch 14: valid_err_rate: 27.160000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 29.070000% averaged train nll: 0.831830 averaged train loss: 1.230509
# At minibatch 22500, batch loss 1.341423, batch nll 0.942196, batch error rate 28.000000%
# At minibatch 22600, batch loss 1.279882, batch nll 0.881101, batch error rate 32.000000%
# At minibatch 22700, batch loss 1.145725, batch nll 0.745441, batch error rate 24.000000%
# At minibatch 22800, batch loss 1.152468, batch nll 0.753341, batch error rate 32.000000%
# At minibatch 22900, batch loss 1.349662, batch nll 0.950401, batch error rate 20.000000%
# At minibatch 23000, batch loss 1.285959, batch nll 0.886265, batch error rate 28.000000%
# At minibatch 23100, batch loss 1.301726, batch nll 0.901562, batch error rate 28.000000%
# At minibatch 23200, batch loss 1.362644, batch nll 0.961965, batch error rate 36.000000%
# At minibatch 23300, batch loss 0.872459, batch nll 0.470798, batch error rate 8.000000%
# At minibatch 23400, batch loss 1.064658, batch nll 0.663372, batch error rate 32.000000%
# At minibatch 23500, batch loss 1.010918, batch nll 0.609764, batch error rate 16.000000%
# At minibatch 23600, batch loss 1.007316, batch nll 0.607032, batch error rate 24.000000%
# At minibatch 23700, batch loss 1.411161, batch nll 1.010886, batch error rate 24.000000%
# At minibatch 23800, batch loss 1.380880, batch nll 0.980456, batch error rate 32.000000%
# At minibatch 23900, batch loss 1.340537, batch nll 0.940311, batch error rate 24.000000%
# At minibatch 24000, batch loss 1.171006, batch nll 0.771159, batch error rate 32.000000%
# After epoch 15: valid_err_rate: 25.910000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 28.445000% averaged train nll: 0.811469 averaged train loss: 1.211649
# At minibatch 24100, batch loss 1.064271, batch nll 0.663089, batch error rate 28.000000%
# At minibatch 24200, batch loss 1.059325, batch nll 0.657563, batch error rate 20.000000%
# At minibatch 24300, batch loss 1.129074, batch nll 0.727410, batch error rate 20.000000%
# At minibatch 24400, batch loss 1.272697, batch nll 0.870498, batch error rate 36.000000%
# At minibatch 24500, batch loss 1.434154, batch nll 1.031289, batch error rate 48.000000%
# At minibatch 24600, batch loss 1.236149, batch nll 0.832665, batch error rate 40.000000%
# At minibatch 24700, batch loss 1.036044, batch nll 0.631393, batch error rate 24.000000%
# At minibatch 24800, batch loss 1.568134, batch nll 1.164346, batch error rate 48.000000%
# At minibatch 24900, batch loss 1.187996, batch nll 0.784461, batch error rate 28.000000%
# At minibatch 25000, batch loss 1.392552, batch nll 0.988687, batch error rate 32.000000%
# At minibatch 25100, batch loss 1.606291, batch nll 1.202375, batch error rate 40.000000%
# At minibatch 25200, batch loss 0.908599, batch nll 0.505687, batch error rate 24.000000%
# At minibatch 25300, batch loss 1.317727, batch nll 0.915844, batch error rate 44.000000%
# At minibatch 25400, batch loss 1.407079, batch nll 1.004829, batch error rate 36.000000%
# At minibatch 25500, batch loss 1.123403, batch nll 0.719732, batch error rate 28.000000%
# At minibatch 25600, batch loss 1.566247, batch nll 1.163057, batch error rate 40.000000%
# After epoch 16: valid_err_rate: 27.140000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 27.992500% averaged train nll: 0.795110 averaged train loss: 1.197820
# At minibatch 25700, batch loss 1.247987, batch nll 0.844156, batch error rate 28.000000%
# At minibatch 25800, batch loss 0.838160, batch nll 0.434513, batch error rate 20.000000%
# At minibatch 25900, batch loss 1.007934, batch nll 0.604243, batch error rate 16.000000%
# At minibatch 26000, batch loss 1.084523, batch nll 0.681532, batch error rate 16.000000%
# At minibatch 26100, batch loss 1.546556, batch nll 1.143493, batch error rate 40.000000%
# At minibatch 26200, batch loss 0.866534, batch nll 0.463375, batch error rate 16.000000%
# At minibatch 26300, batch loss 1.224840, batch nll 0.820779, batch error rate 36.000000%
# At minibatch 26400, batch loss 1.091789, batch nll 0.688573, batch error rate 28.000000%
# At minibatch 26500, batch loss 1.059030, batch nll 0.655405, batch error rate 24.000000%
# At minibatch 26600, batch loss 1.170596, batch nll 0.767343, batch error rate 24.000000%
# At minibatch 26700, batch loss 1.229893, batch nll 0.826133, batch error rate 28.000000%
# At minibatch 26800, batch loss 1.620567, batch nll 1.216257, batch error rate 32.000000%
# At minibatch 26900, batch loss 1.667144, batch nll 1.263563, batch error rate 52.000000%
# At minibatch 27000, batch loss 1.003830, batch nll 0.601191, batch error rate 32.000000%
# At minibatch 27100, batch loss 1.133560, batch nll 0.729875, batch error rate 28.000000%
# At minibatch 27200, batch loss 0.987442, batch nll 0.584400, batch error rate 28.000000%
# After epoch 17: valid_err_rate: 25.210000% currently going to do 26 epochs
# After epoch 17: averaged train_err_rate: 26.815000% averaged train nll: 0.769198 averaged train loss: 1.172738
# At minibatch 27300, batch loss 1.099285, batch nll 0.695163, batch error rate 32.000000%
# At minibatch 27400, batch loss 0.931545, batch nll 0.526066, batch error rate 16.000000%
# At minibatch 27500, batch loss 1.021551, batch nll 0.615972, batch error rate 16.000000%
# At minibatch 27600, batch loss 1.116017, batch nll 0.710326, batch error rate 24.000000%
# At minibatch 27700, batch loss 1.062179, batch nll 0.655320, batch error rate 28.000000%
# At minibatch 27800, batch loss 1.091971, batch nll 0.686354, batch error rate 28.000000%
# At minibatch 27900, batch loss 1.268069, batch nll 0.862781, batch error rate 28.000000%
# At minibatch 28000, batch loss 1.246892, batch nll 0.840339, batch error rate 28.000000%
# At minibatch 28100, batch loss 1.316308, batch nll 0.910038, batch error rate 40.000000%
# At minibatch 28200, batch loss 1.282632, batch nll 0.876302, batch error rate 36.000000%
# At minibatch 28300, batch loss 0.916255, batch nll 0.510502, batch error rate 20.000000%
# At minibatch 28400, batch loss 1.156150, batch nll 0.749561, batch error rate 36.000000%
# At minibatch 28500, batch loss 1.026597, batch nll 0.621102, batch error rate 20.000000%
# At minibatch 28600, batch loss 0.818407, batch nll 0.414424, batch error rate 16.000000%
# At minibatch 28700, batch loss 1.017661, batch nll 0.613767, batch error rate 24.000000%
# At minibatch 28800, batch loss 1.206182, batch nll 0.802163, batch error rate 28.000000%
# After epoch 18: valid_err_rate: 28.650000% currently going to do 26 epochs
# After epoch 18: averaged train_err_rate: 26.460000% averaged train nll: 0.752782 averaged train loss: 1.158244
# At minibatch 28900, batch loss 1.155579, batch nll 0.750301, batch error rate 32.000000%
# At minibatch 29000, batch loss 1.298233, batch nll 0.891972, batch error rate 28.000000%
# At minibatch 29100, batch loss 1.208878, batch nll 0.801413, batch error rate 36.000000%
# At minibatch 29200, batch loss 1.285422, batch nll 0.878353, batch error rate 32.000000%
# At minibatch 29300, batch loss 1.077985, batch nll 0.672107, batch error rate 24.000000%
# At minibatch 29400, batch loss 1.522690, batch nll 1.116061, batch error rate 36.000000%
# At minibatch 29500, batch loss 0.923646, batch nll 0.516239, batch error rate 16.000000%
# At minibatch 29600, batch loss 1.398499, batch nll 0.991682, batch error rate 40.000000%
# At minibatch 29700, batch loss 1.032212, batch nll 0.626005, batch error rate 28.000000%
# At minibatch 29800, batch loss 1.262675, batch nll 0.856211, batch error rate 36.000000%
# At minibatch 29900, batch loss 1.594857, batch nll 1.188836, batch error rate 32.000000%
# At minibatch 30000, batch loss 1.446429, batch nll 1.040462, batch error rate 44.000000%
# At minibatch 30100, batch loss 1.118565, batch nll 0.713637, batch error rate 20.000000%
# At minibatch 30200, batch loss 1.213704, batch nll 0.808756, batch error rate 32.000000%
# At minibatch 30300, batch loss 0.931660, batch nll 0.525971, batch error rate 16.000000%
# At minibatch 30400, batch loss 1.319471, batch nll 0.913357, batch error rate 32.000000%
# After epoch 19: valid_err_rate: 24.680000% currently going to do 29 epochs
# After epoch 19: averaged train_err_rate: 25.575000% averaged train nll: 0.738821 averaged train loss: 1.144872
# At minibatch 30500, batch loss 1.214205, batch nll 0.808041, batch error rate 28.000000%
# At minibatch 30600, batch loss 0.935298, batch nll 0.529260, batch error rate 16.000000%
# At minibatch 30700, batch loss 1.139623, batch nll 0.732615, batch error rate 28.000000%
# At minibatch 30800, batch loss 1.401904, batch nll 0.995305, batch error rate 40.000000%
# At minibatch 30900, batch loss 1.001688, batch nll 0.594524, batch error rate 24.000000%
# At minibatch 31000, batch loss 1.084834, batch nll 0.677970, batch error rate 28.000000%
# At minibatch 31100, batch loss 1.243401, batch nll 0.836493, batch error rate 48.000000%
# At minibatch 31200, batch loss 1.169758, batch nll 0.762602, batch error rate 32.000000%
# At minibatch 31300, batch loss 1.241505, batch nll 0.833874, batch error rate 24.000000%
# At minibatch 31400, batch loss 1.091295, batch nll 0.684273, batch error rate 28.000000%
# At minibatch 31500, batch loss 0.936767, batch nll 0.529435, batch error rate 20.000000%
# At minibatch 31600, batch loss 1.151410, batch nll 0.744678, batch error rate 20.000000%
# At minibatch 31700, batch loss 1.010821, batch nll 0.605260, batch error rate 16.000000%
# At minibatch 31800, batch loss 1.414751, batch nll 1.008876, batch error rate 36.000000%
# At minibatch 31900, batch loss 1.184365, batch nll 0.778992, batch error rate 24.000000%
# At minibatch 32000, batch loss 1.498737, batch nll 1.092293, batch error rate 36.000000%
# After epoch 20: valid_err_rate: 26.520000% currently going to do 29 epochs
# After epoch 20: averaged train_err_rate: 25.367500% averaged train nll: 0.723348 averaged train loss: 1.130024
# At minibatch 32100, batch loss 1.233593, batch nll 0.825925, batch error rate 24.000000%
# At minibatch 32200, batch loss 1.090894, batch nll 0.682438, batch error rate 24.000000%
# At minibatch 32300, batch loss 0.920630, batch nll 0.512050, batch error rate 20.000000%
# At minibatch 32400, batch loss 1.266132, batch nll 0.857156, batch error rate 32.000000%
# At minibatch 32500, batch loss 1.363414, batch nll 0.954471, batch error rate 36.000000%
# At minibatch 32600, batch loss 1.367547, batch nll 0.958766, batch error rate 44.000000%
# At minibatch 32700, batch loss 1.214805, batch nll 0.806015, batch error rate 24.000000%
# At minibatch 32800, batch loss 0.888869, batch nll 0.480234, batch error rate 16.000000%
# At minibatch 32900, batch loss 1.204336, batch nll 0.795555, batch error rate 32.000000%
# At minibatch 33000, batch loss 1.351887, batch nll 0.942517, batch error rate 32.000000%
# At minibatch 33100, batch loss 1.339182, batch nll 0.930785, batch error rate 20.000000%
# At minibatch 33200, batch loss 1.156493, batch nll 0.748252, batch error rate 36.000000%
# At minibatch 33300, batch loss 1.044787, batch nll 0.636091, batch error rate 24.000000%
# At minibatch 33400, batch loss 1.134213, batch nll 0.725049, batch error rate 28.000000%
# At minibatch 33500, batch loss 1.232230, batch nll 0.823801, batch error rate 32.000000%
# At minibatch 33600, batch loss 0.914073, batch nll 0.506186, batch error rate 16.000000%
# After epoch 21: valid_err_rate: 24.840000% currently going to do 29 epochs
# After epoch 21: averaged train_err_rate: 24.952500% averaged train nll: 0.712654 averaged train loss: 1.121262
# At minibatch 33700, batch loss 1.423505, batch nll 1.015246, batch error rate 32.000000%
# At minibatch 33800, batch loss 0.911655, batch nll 0.502175, batch error rate 12.000000%
# At minibatch 33900, batch loss 1.191891, batch nll 0.782320, batch error rate 20.000000%
# At minibatch 34000, batch loss 1.311493, batch nll 0.901983, batch error rate 28.000000%
# At minibatch 34100, batch loss 1.178355, batch nll 0.768375, batch error rate 24.000000%
# At minibatch 34200, batch loss 1.259757, batch nll 0.849673, batch error rate 24.000000%
# At minibatch 34300, batch loss 1.138194, batch nll 0.727489, batch error rate 28.000000%
# At minibatch 34400, batch loss 1.334878, batch nll 0.924398, batch error rate 36.000000%
# At minibatch 34500, batch loss 0.996734, batch nll 0.586046, batch error rate 20.000000%
# At minibatch 34600, batch loss 1.007167, batch nll 0.597563, batch error rate 20.000000%
# At minibatch 34700, batch loss 1.152003, batch nll 0.742480, batch error rate 28.000000%
# At minibatch 34800, batch loss 0.906079, batch nll 0.496064, batch error rate 16.000000%
# At minibatch 34900, batch loss 1.211328, batch nll 0.801635, batch error rate 36.000000%
# At minibatch 35000, batch loss 1.201120, batch nll 0.791612, batch error rate 32.000000%
# At minibatch 35100, batch loss 1.259417, batch nll 0.851143, batch error rate 32.000000%
# At minibatch 35200, batch loss 1.042892, batch nll 0.635127, batch error rate 20.000000%
# After epoch 22: valid_err_rate: 22.640000% currently going to do 34 epochs
# After epoch 22: averaged train_err_rate: 24.532500% averaged train nll: 0.702645 averaged train loss: 1.112195
# At minibatch 35300, batch loss 0.971379, batch nll 0.561842, batch error rate 28.000000%
# At minibatch 35400, batch loss 0.943583, batch nll 0.533314, batch error rate 12.000000%
# At minibatch 35500, batch loss 1.086982, batch nll 0.676551, batch error rate 36.000000%
# At minibatch 35600, batch loss 0.961859, batch nll 0.552150, batch error rate 32.000000%
# At minibatch 35700, batch loss 1.044189, batch nll 0.632993, batch error rate 24.000000%
# At minibatch 35800, batch loss 1.163428, batch nll 0.752309, batch error rate 20.000000%
# At minibatch 35900, batch loss 1.176266, batch nll 0.765400, batch error rate 24.000000%
# At minibatch 36000, batch loss 1.129045, batch nll 0.717993, batch error rate 28.000000%
# At minibatch 36100, batch loss 1.004169, batch nll 0.592382, batch error rate 16.000000%
# At minibatch 36200, batch loss 0.975874, batch nll 0.564499, batch error rate 16.000000%
# At minibatch 36300, batch loss 1.189810, batch nll 0.777976, batch error rate 28.000000%
# At minibatch 36400, batch loss 0.851233, batch nll 0.439796, batch error rate 16.000000%
# At minibatch 36500, batch loss 1.102915, batch nll 0.691774, batch error rate 24.000000%
# At minibatch 36600, batch loss 0.975437, batch nll 0.565132, batch error rate 20.000000%
# At minibatch 36700, batch loss 0.943161, batch nll 0.533037, batch error rate 20.000000%
# At minibatch 36800, batch loss 1.083890, batch nll 0.674537, batch error rate 16.000000%
# After epoch 23: valid_err_rate: 25.420000% currently going to do 34 epochs
# After epoch 23: averaged train_err_rate: 24.095000% averaged train nll: 0.687208 averaged train loss: 1.097930
# At minibatch 36900, batch loss 1.352153, batch nll 0.941619, batch error rate 28.000000%
# At minibatch 37000, batch loss 0.908859, batch nll 0.498152, batch error rate 16.000000%
# At minibatch 37100, batch loss 0.927515, batch nll 0.516767, batch error rate 16.000000%
# At minibatch 37200, batch loss 1.209053, batch nll 0.797746, batch error rate 28.000000%
# At minibatch 37300, batch loss 1.099161, batch nll 0.687284, batch error rate 24.000000%
# At minibatch 37400, batch loss 1.192579, batch nll 0.780317, batch error rate 24.000000%
# At minibatch 37500, batch loss 1.307597, batch nll 0.896385, batch error rate 28.000000%
# At minibatch 37600, batch loss 0.925751, batch nll 0.514353, batch error rate 20.000000%
# At minibatch 37700, batch loss 1.169324, batch nll 0.757831, batch error rate 24.000000%
# At minibatch 37800, batch loss 0.920646, batch nll 0.509811, batch error rate 12.000000%
# At minibatch 37900, batch loss 1.021030, batch nll 0.609414, batch error rate 16.000000%
# At minibatch 38000, batch loss 0.881176, batch nll 0.468927, batch error rate 8.000000%
# At minibatch 38100, batch loss 1.335612, batch nll 0.923651, batch error rate 32.000000%
# At minibatch 38200, batch loss 0.704877, batch nll 0.292803, batch error rate 12.000000%
# At minibatch 38300, batch loss 1.161978, batch nll 0.750853, batch error rate 20.000000%
# At minibatch 38400, batch loss 0.997476, batch nll 0.585981, batch error rate 20.000000%
# After epoch 24: valid_err_rate: 23.250000% currently going to do 34 epochs
# After epoch 24: averaged train_err_rate: 23.997500% averaged train nll: 0.681831 averaged train loss: 1.093199
# At minibatch 38500, batch loss 1.276801, batch nll 0.864830, batch error rate 40.000000%
# At minibatch 38600, batch loss 1.237183, batch nll 0.825087, batch error rate 28.000000%
# At minibatch 38700, batch loss 1.602824, batch nll 1.190759, batch error rate 32.000000%
# At minibatch 38800, batch loss 1.043783, batch nll 0.632525, batch error rate 28.000000%
# At minibatch 38900, batch loss 1.505187, batch nll 1.093037, batch error rate 44.000000%
# At minibatch 39000, batch loss 0.930553, batch nll 0.518485, batch error rate 8.000000%
# At minibatch 39100, batch loss 1.407096, batch nll 0.994082, batch error rate 24.000000%
# At minibatch 39200, batch loss 0.882778, batch nll 0.468917, batch error rate 8.000000%
# At minibatch 39300, batch loss 0.965411, batch nll 0.552155, batch error rate 16.000000%
# At minibatch 39400, batch loss 1.142655, batch nll 0.730107, batch error rate 28.000000%
# At minibatch 39500, batch loss 1.331845, batch nll 0.919652, batch error rate 24.000000%
# At minibatch 39600, batch loss 0.994693, batch nll 0.582311, batch error rate 16.000000%
# At minibatch 39700, batch loss 0.799560, batch nll 0.387131, batch error rate 8.000000%
# At minibatch 39800, batch loss 0.983629, batch nll 0.572234, batch error rate 24.000000%
# At minibatch 39900, batch loss 1.213301, batch nll 0.802227, batch error rate 36.000000%
# At minibatch 40000, batch loss 1.134857, batch nll 0.723291, batch error rate 28.000000%
# After epoch 25: valid_err_rate: 22.840000% currently going to do 34 epochs
# After epoch 25: averaged train_err_rate: 23.422500% averaged train nll: 0.672069 averaged train loss: 1.084303
# At minibatch 40100, batch loss 1.008132, batch nll 0.595984, batch error rate 20.000000%
# At minibatch 40200, batch loss 1.171052, batch nll 0.758568, batch error rate 32.000000%
# At minibatch 40300, batch loss 1.191368, batch nll 0.777841, batch error rate 28.000000%
# At minibatch 40400, batch loss 0.960103, batch nll 0.546388, batch error rate 16.000000%
# At minibatch 40500, batch loss 1.237195, batch nll 0.823238, batch error rate 32.000000%
# At minibatch 40600, batch loss 0.958768, batch nll 0.545352, batch error rate 16.000000%
# At minibatch 40700, batch loss 0.887345, batch nll 0.473136, batch error rate 12.000000%
# At minibatch 40800, batch loss 1.007299, batch nll 0.593119, batch error rate 20.000000%
# At minibatch 40900, batch loss 1.023516, batch nll 0.609334, batch error rate 16.000000%
# At minibatch 41000, batch loss 0.876144, batch nll 0.462148, batch error rate 16.000000%
# At minibatch 41100, batch loss 1.135924, batch nll 0.721701, batch error rate 28.000000%
# At minibatch 41200, batch loss 0.999361, batch nll 0.585304, batch error rate 16.000000%
# At minibatch 41300, batch loss 1.325361, batch nll 0.911109, batch error rate 36.000000%
# At minibatch 41400, batch loss 0.858420, batch nll 0.443849, batch error rate 20.000000%
# At minibatch 41500, batch loss 1.206979, batch nll 0.792046, batch error rate 40.000000%
# At minibatch 41600, batch loss 1.194296, batch nll 0.780365, batch error rate 36.000000%
# After epoch 26: valid_err_rate: 22.980000% currently going to do 34 epochs
# After epoch 26: averaged train_err_rate: 22.862500% averaged train nll: 0.655639 averaged train loss: 1.069535
# At minibatch 41700, batch loss 0.952786, batch nll 0.537582, batch error rate 24.000000%
# At minibatch 41800, batch loss 0.939407, batch nll 0.523964, batch error rate 12.000000%
# At minibatch 41900, batch loss 0.806581, batch nll 0.391296, batch error rate 8.000000%
# At minibatch 42000, batch loss 0.959467, batch nll 0.544140, batch error rate 20.000000%
# At minibatch 42100, batch loss 0.998440, batch nll 0.583403, batch error rate 28.000000%
# At minibatch 42200, batch loss 0.816911, batch nll 0.400749, batch error rate 8.000000%
# At minibatch 42300, batch loss 0.748641, batch nll 0.332502, batch error rate 16.000000%
# At minibatch 42400, batch loss 1.288687, batch nll 0.872578, batch error rate 28.000000%
# At minibatch 42500, batch loss 1.245017, batch nll 0.828579, batch error rate 28.000000%
# At minibatch 42600, batch loss 0.930083, batch nll 0.514209, batch error rate 12.000000%
# At minibatch 42700, batch loss 0.928816, batch nll 0.512363, batch error rate 24.000000%
# At minibatch 42800, batch loss 0.983404, batch nll 0.567489, batch error rate 12.000000%
# At minibatch 42900, batch loss 1.078302, batch nll 0.662426, batch error rate 24.000000%
# At minibatch 43000, batch loss 1.593982, batch nll 1.178674, batch error rate 36.000000%
# At minibatch 43100, batch loss 1.256349, batch nll 0.841376, batch error rate 24.000000%
# At minibatch 43200, batch loss 0.835883, batch nll 0.421046, batch error rate 16.000000%
# After epoch 27: valid_err_rate: 21.760000% currently going to do 41 epochs
# After epoch 27: averaged train_err_rate: 22.457500% averaged train nll: 0.650551 averaged train loss: 1.066205
# At minibatch 43300, batch loss 0.866649, batch nll 0.450995, batch error rate 16.000000%
# At minibatch 43400, batch loss 1.092775, batch nll 0.676323, batch error rate 20.000000%
# At minibatch 43500, batch loss 1.393366, batch nll 0.976674, batch error rate 40.000000%
# At minibatch 43600, batch loss 1.742572, batch nll 1.325091, batch error rate 52.000000%
# At minibatch 43700, batch loss 1.084183, batch nll 0.665715, batch error rate 24.000000%
# At minibatch 43800, batch loss 1.274930, batch nll 0.857810, batch error rate 24.000000%
# At minibatch 43900, batch loss 1.222359, batch nll 0.805103, batch error rate 28.000000%
# At minibatch 44000, batch loss 0.970797, batch nll 0.553945, batch error rate 20.000000%
# At minibatch 44100, batch loss 1.091905, batch nll 0.675487, batch error rate 24.000000%
# At minibatch 44200, batch loss 1.106830, batch nll 0.690340, batch error rate 20.000000%
# At minibatch 44300, batch loss 0.843444, batch nll 0.426965, batch error rate 16.000000%
# At minibatch 44400, batch loss 1.108971, batch nll 0.691845, batch error rate 24.000000%
# At minibatch 44500, batch loss 1.124158, batch nll 0.707260, batch error rate 24.000000%
# At minibatch 44600, batch loss 1.168245, batch nll 0.751305, batch error rate 32.000000%
# At minibatch 44700, batch loss 1.174155, batch nll 0.756396, batch error rate 24.000000%
# At minibatch 44800, batch loss 1.161133, batch nll 0.744125, batch error rate 32.000000%
# After epoch 28: valid_err_rate: 22.870000% currently going to do 41 epochs
# After epoch 28: averaged train_err_rate: 22.307500% averaged train nll: 0.638433 averaged train loss: 1.055307
# At minibatch 44900, batch loss 1.134687, batch nll 0.716986, batch error rate 28.000000%
# At minibatch 45000, batch loss 0.964879, batch nll 0.546656, batch error rate 20.000000%
# At minibatch 45100, batch loss 1.183573, batch nll 0.765475, batch error rate 28.000000%
# At minibatch 45200, batch loss 0.813519, batch nll 0.395044, batch error rate 12.000000%
# At minibatch 45300, batch loss 1.079759, batch nll 0.661285, batch error rate 20.000000%
# At minibatch 45400, batch loss 0.774705, batch nll 0.356676, batch error rate 8.000000%
# At minibatch 45500, batch loss 1.171081, batch nll 0.753082, batch error rate 36.000000%
# At minibatch 45600, batch loss 0.885219, batch nll 0.467062, batch error rate 16.000000%
# At minibatch 45700, batch loss 1.602486, batch nll 1.185092, batch error rate 40.000000%
# At minibatch 45800, batch loss 0.885429, batch nll 0.468216, batch error rate 16.000000%
# At minibatch 45900, batch loss 1.101610, batch nll 0.684343, batch error rate 28.000000%
# At minibatch 46000, batch loss 1.017853, batch nll 0.600593, batch error rate 20.000000%
# At minibatch 46100, batch loss 0.943897, batch nll 0.527058, batch error rate 20.000000%
# At minibatch 46200, batch loss 1.011934, batch nll 0.594798, batch error rate 16.000000%
# At minibatch 46300, batch loss 1.211524, batch nll 0.794984, batch error rate 32.000000%
# At minibatch 46400, batch loss 0.750274, batch nll 0.333485, batch error rate 12.000000%
# After epoch 29: valid_err_rate: 21.870000% currently going to do 41 epochs
# After epoch 29: averaged train_err_rate: 22.127500% averaged train nll: 0.629866 averaged train loss: 1.047552
# At minibatch 46500, batch loss 1.260650, batch nll 0.843210, batch error rate 28.000000%
# At minibatch 46600, batch loss 0.837260, batch nll 0.418431, batch error rate 12.000000%
# At minibatch 46700, batch loss 0.995568, batch nll 0.576826, batch error rate 16.000000%
# At minibatch 46800, batch loss 0.688474, batch nll 0.268939, batch error rate 8.000000%
# At minibatch 46900, batch loss 0.861243, batch nll 0.442369, batch error rate 12.000000%
# At minibatch 47000, batch loss 0.636483, batch nll 0.216570, batch error rate 4.000000%
# At minibatch 47100, batch loss 1.504039, batch nll 1.084385, batch error rate 40.000000%
# At minibatch 47200, batch loss 0.937107, batch nll 0.517645, batch error rate 20.000000%
# At minibatch 47300, batch loss 1.060867, batch nll 0.641129, batch error rate 24.000000%
# At minibatch 47400, batch loss 1.001239, batch nll 0.580938, batch error rate 16.000000%
# At minibatch 47500, batch loss 0.928888, batch nll 0.508676, batch error rate 16.000000%
# At minibatch 47600, batch loss 1.151983, batch nll 0.732027, batch error rate 20.000000%
# At minibatch 47700, batch loss 0.993648, batch nll 0.573366, batch error rate 20.000000%
# At minibatch 47800, batch loss 0.829969, batch nll 0.409444, batch error rate 16.000000%
# At minibatch 47900, batch loss 1.329441, batch nll 0.909873, batch error rate 32.000000%
# At minibatch 48000, batch loss 0.827224, batch nll 0.407493, batch error rate 16.000000%
# ...
# At minibatch 146300, batch loss 0.696317, batch nll 0.220129, batch error rate 12.000000%
# At minibatch 146400, batch loss 1.235311, batch nll 0.759059, batch error rate 20.000000%
# At minibatch 146500, batch loss 0.660177, batch nll 0.183991, batch error rate 4.000000%
# At minibatch 146600, batch loss 0.976346, batch nll 0.500092, batch error rate 12.000000%
# At minibatch 146700, batch loss 0.664022, batch nll 0.187736, batch error rate 4.000000%
# At minibatch 146800, batch loss 1.132547, batch nll 0.656179, batch error rate 28.000000%
# At minibatch 146900, batch loss 0.747363, batch nll 0.271119, batch error rate 12.000000%
# At minibatch 147000, batch loss 0.944362, batch nll 0.468055, batch error rate 12.000000%
# At minibatch 147100, batch loss 0.790629, batch nll 0.314237, batch error rate 4.000000%
# At minibatch 147200, batch loss 0.814805, batch nll 0.338250, batch error rate 12.000000%
# After epoch 92: valid_err_rate: 18.520000% currently going to do 133 epochs
# After epoch 92: averaged train_err_rate: 11.950000% averaged train nll: 0.355026 averaged train loss: 0.831216
# At minibatch 147300, batch loss 0.736723, batch nll 0.260099, batch error rate 4.000000%
# At minibatch 147400, batch loss 0.933943, batch nll 0.457347, batch error rate 28.000000%
# At minibatch 147500, batch loss 0.833979, batch nll 0.357221, batch error rate 12.000000%
# At minibatch 147600, batch loss 0.865886, batch nll 0.388948, batch error rate 16.000000%
# At minibatch 147700, batch loss 0.701573, batch nll 0.224612, batch error rate 4.000000%
# At minibatch 147800, batch loss 1.089955, batch nll 0.612906, batch error rate 20.000000%
# At minibatch 147900, batch loss 0.715890, batch nll 0.238842, batch error rate 4.000000%
# At minibatch 148000, batch loss 0.708356, batch nll 0.231411, batch error rate 12.000000%
# At minibatch 148100, batch loss 0.893818, batch nll 0.416964, batch error rate 12.000000%
# At minibatch 148200, batch loss 0.697062, batch nll 0.220289, batch error rate 4.000000%
# At minibatch 148300, batch loss 0.816692, batch nll 0.339883, batch error rate 12.000000%
# At minibatch 148400, batch loss 0.864573, batch nll 0.387583, batch error rate 20.000000%
# At minibatch 148500, batch loss 0.859322, batch nll 0.382267, batch error rate 16.000000%
# At minibatch 148600, batch loss 1.304117, batch nll 0.827018, batch error rate 32.000000%
# At minibatch 148700, batch loss 0.754826, batch nll 0.277626, batch error rate 8.000000%
# At minibatch 148800, batch loss 0.753057, batch nll 0.275997, batch error rate 8.000000%
# After epoch 93: valid_err_rate: 18.410000% currently going to do 133 epochs
# After epoch 93: averaged train_err_rate: 11.480000% averaged train nll: 0.345960 averaged train loss: 0.822867
# At minibatch 148900, batch loss 0.721107, batch nll 0.243933, batch error rate 8.000000%
# At minibatch 149000, batch loss 0.775738, batch nll 0.298457, batch error rate 4.000000%
# At minibatch 149100, batch loss 0.822577, batch nll 0.345104, batch error rate 8.000000%
# At minibatch 149200, batch loss 0.751626, batch nll 0.273909, batch error rate 4.000000%
# At minibatch 149300, batch loss 0.938985, batch nll 0.461044, batch error rate 24.000000%
# At minibatch 149400, batch loss 0.810478, batch nll 0.332457, batch error rate 8.000000%
# At minibatch 149500, batch loss 0.693999, batch nll 0.216056, batch error rate 4.000000%
# At minibatch 149600, batch loss 0.913935, batch nll 0.435992, batch error rate 20.000000%
# At minibatch 149700, batch loss 0.902174, batch nll 0.423967, batch error rate 8.000000%
# At minibatch 149800, batch loss 0.889518, batch nll 0.411370, batch error rate 12.000000%
# At minibatch 149900, batch loss 0.846843, batch nll 0.368525, batch error rate 12.000000%
# At minibatch 150000, batch loss 0.842294, batch nll 0.364121, batch error rate 20.000000%
# At minibatch 150100, batch loss 0.924818, batch nll 0.446550, batch error rate 12.000000%
# At minibatch 150200, batch loss 1.052591, batch nll 0.574368, batch error rate 32.000000%
# At minibatch 150300, batch loss 1.038830, batch nll 0.560518, batch error rate 20.000000%
# At minibatch 150400, batch loss 0.745502, batch nll 0.267212, batch error rate 12.000000%
# After epoch 94: valid_err_rate: 18.320000% currently going to do 133 epochs
# After epoch 94: averaged train_err_rate: 11.480000% averaged train nll: 0.343284 averaged train loss: 0.821208
# At minibatch 150500, batch loss 0.871157, batch nll 0.392686, batch error rate 16.000000%
# At minibatch 150600, batch loss 0.844947, batch nll 0.366458, batch error rate 16.000000%
# At minibatch 150700, batch loss 0.687373, batch nll 0.208815, batch error rate 4.000000%
# At minibatch 150800, batch loss 1.108902, batch nll 0.630206, batch error rate 32.000000%
# At minibatch 150900, batch loss 0.799429, batch nll 0.320547, batch error rate 16.000000%
# At minibatch 151000, batch loss 0.859991, batch nll 0.381172, batch error rate 16.000000%
# At minibatch 151100, batch loss 0.842272, batch nll 0.363444, batch error rate 16.000000%
# At minibatch 151200, batch loss 0.723279, batch nll 0.244452, batch error rate 8.000000%
# At minibatch 151300, batch loss 0.616115, batch nll 0.137200, batch error rate 4.000000%
# At minibatch 151400, batch loss 0.798905, batch nll 0.319848, batch error rate 12.000000%
# At minibatch 151500, batch loss 0.634898, batch nll 0.155836, batch error rate 0.000000%
# At minibatch 151600, batch loss 0.660821, batch nll 0.181930, batch error rate 4.000000%
# At minibatch 151700, batch loss 0.989916, batch nll 0.510983, batch error rate 16.000000%
# At minibatch 151800, batch loss 0.797431, batch nll 0.318601, batch error rate 12.000000%
# At minibatch 151900, batch loss 1.007140, batch nll 0.528324, batch error rate 24.000000%
# At minibatch 152000, batch loss 0.872299, batch nll 0.393609, batch error rate 12.000000%
# After epoch 95: valid_err_rate: 18.160000% currently going to do 133 epochs
# After epoch 95: averaged train_err_rate: 11.407500% averaged train nll: 0.342414 averaged train loss: 0.821196
# At minibatch 152100, batch loss 0.576259, batch nll 0.097360, batch error rate 0.000000%
# At minibatch 152200, batch loss 0.895016, batch nll 0.415946, batch error rate 20.000000%
# At minibatch 152300, batch loss 1.047922, batch nll 0.568963, batch error rate 20.000000%
# At minibatch 152400, batch loss 0.887745, batch nll 0.408572, batch error rate 16.000000%
# At minibatch 152500, batch loss 0.778097, batch nll 0.298993, batch error rate 12.000000%
# At minibatch 152600, batch loss 0.858186, batch nll 0.379062, batch error rate 16.000000%
# At minibatch 152700, batch loss 0.763267, batch nll 0.284350, batch error rate 8.000000%
# At minibatch 152800, batch loss 0.763435, batch nll 0.284372, batch error rate 8.000000%
# At minibatch 152900, batch loss 0.691810, batch nll 0.212706, batch error rate 8.000000%
# At minibatch 153000, batch loss 0.777477, batch nll 0.298245, batch error rate 8.000000%
# At minibatch 153100, batch loss 0.835852, batch nll 0.356372, batch error rate 8.000000%
# At minibatch 153200, batch loss 1.173803, batch nll 0.694103, batch error rate 20.000000%
# At minibatch 153300, batch loss 0.894348, batch nll 0.414724, batch error rate 16.000000%
# At minibatch 153400, batch loss 0.835357, batch nll 0.355606, batch error rate 12.000000%
# At minibatch 153500, batch loss 0.619866, batch nll 0.140168, batch error rate 0.000000%
# At minibatch 153600, batch loss 1.075434, batch nll 0.595723, batch error rate 16.000000%
# After epoch 96: valid_err_rate: 17.630000% currently going to do 145 epochs
# After epoch 96: averaged train_err_rate: 11.402500% averaged train nll: 0.342406 averaged train loss: 0.821682
# At minibatch 153700, batch loss 0.664269, batch nll 0.184208, batch error rate 0.000000%
# At minibatch 153800, batch loss 0.662702, batch nll 0.182523, batch error rate 4.000000%
# At minibatch 153900, batch loss 0.661599, batch nll 0.181236, batch error rate 4.000000%
# At minibatch 154000, batch loss 0.759658, batch nll 0.279160, batch error rate 8.000000%
# At minibatch 154100, batch loss 0.693048, batch nll 0.212418, batch error rate 12.000000%
# At minibatch 154200, batch loss 1.113285, batch nll 0.632560, batch error rate 16.000000%
# At minibatch 154300, batch loss 0.706578, batch nll 0.225929, batch error rate 8.000000%
# At minibatch 154400, batch loss 0.831617, batch nll 0.351129, batch error rate 20.000000%
# At minibatch 154500, batch loss 0.690539, batch nll 0.209753, batch error rate 8.000000%
# At minibatch 154600, batch loss 0.940662, batch nll 0.460186, batch error rate 16.000000%
# At minibatch 154700, batch loss 0.704099, batch nll 0.223581, batch error rate 12.000000%
# At minibatch 154800, batch loss 0.840947, batch nll 0.360425, batch error rate 8.000000%
# At minibatch 154900, batch loss 1.071359, batch nll 0.591099, batch error rate 24.000000%
# At minibatch 155000, batch loss 0.660294, batch nll 0.180371, batch error rate 8.000000%
# At minibatch 155100, batch loss 0.873866, batch nll 0.393801, batch error rate 8.000000%
# At minibatch 155200, batch loss 0.843373, batch nll 0.363378, batch error rate 12.000000%
# After epoch 97: valid_err_rate: 17.330000% currently going to do 146 epochs
# After epoch 97: averaged train_err_rate: 11.360000% averaged train nll: 0.335431 averaged train loss: 0.815801
# At minibatch 155300, batch loss 0.705983, batch nll 0.225764, batch error rate 8.000000%
# At minibatch 155400, batch loss 0.941855, batch nll 0.461467, batch error rate 20.000000%
# At minibatch 155500, batch loss 0.788475, batch nll 0.308004, batch error rate 8.000000%
# At minibatch 155600, batch loss 0.781138, batch nll 0.300515, batch error rate 12.000000%
# At minibatch 155700, batch loss 0.749094, batch nll 0.268254, batch error rate 8.000000%
# At minibatch 155800, batch loss 0.718077, batch nll 0.237404, batch error rate 8.000000%
# At minibatch 155900, batch loss 0.839053, batch nll 0.358387, batch error rate 12.000000%
# At minibatch 156000, batch loss 0.781041, batch nll 0.300138, batch error rate 12.000000%
# At minibatch 156100, batch loss 0.841893, batch nll 0.360958, batch error rate 8.000000%
# At minibatch 156200, batch loss 0.709212, batch nll 0.228365, batch error rate 4.000000%
# At minibatch 156300, batch loss 1.066646, batch nll 0.585708, batch error rate 28.000000%
# At minibatch 156400, batch loss 0.630554, batch nll 0.149647, batch error rate 8.000000%
# At minibatch 156500, batch loss 0.680487, batch nll 0.199565, batch error rate 8.000000%
# At minibatch 156600, batch loss 1.087665, batch nll 0.606876, batch error rate 24.000000%
# At minibatch 156700, batch loss 0.842199, batch nll 0.361567, batch error rate 12.000000%
# At minibatch 156800, batch loss 0.764696, batch nll 0.284112, batch error rate 12.000000%
# After epoch 98: valid_err_rate: 18.720000% currently going to do 146 epochs
# After epoch 98: averaged train_err_rate: 11.402500% averaged train nll: 0.337260 averaged train loss: 0.817948
# At minibatch 156900, batch loss 0.718424, batch nll 0.237441, batch error rate 12.000000%
# At minibatch 157000, batch loss 0.903425, batch nll 0.422469, batch error rate 16.000000%
# At minibatch 157100, batch loss 1.174398, batch nll 0.693290, batch error rate 24.000000%
# At minibatch 157200, batch loss 0.894202, batch nll 0.413155, batch error rate 24.000000%
# At minibatch 157300, batch loss 0.740923, batch nll 0.259773, batch error rate 8.000000%
# At minibatch 157400, batch loss 0.844545, batch nll 0.363261, batch error rate 4.000000%
# At minibatch 157500, batch loss 0.673836, batch nll 0.192706, batch error rate 4.000000%
# At minibatch 157600, batch loss 0.774451, batch nll 0.293368, batch error rate 12.000000%
# At minibatch 157700, batch loss 0.964679, batch nll 0.483828, batch error rate 16.000000%
# At minibatch 157800, batch loss 0.753024, batch nll 0.272177, batch error rate 12.000000%
# At minibatch 157900, batch loss 0.984829, batch nll 0.503591, batch error rate 16.000000%
# At minibatch 158000, batch loss 0.729559, batch nll 0.248273, batch error rate 8.000000%
# At minibatch 158100, batch loss 0.788625, batch nll 0.307487, batch error rate 4.000000%
# At minibatch 158200, batch loss 0.884718, batch nll 0.403650, batch error rate 20.000000%
# At minibatch 158300, batch loss 0.827118, batch nll 0.346172, batch error rate 12.000000%
# At minibatch 158400, batch loss 1.007431, batch nll 0.526626, batch error rate 20.000000%
# After epoch 99: valid_err_rate: 18.660000% currently going to do 146 epochs
# After epoch 99: averaged train_err_rate: 10.877500% averaged train nll: 0.332815 averaged train loss: 0.813879
# At minibatch 158500, batch loss 0.960502, batch nll 0.479627, batch error rate 24.000000%
# At minibatch 158600, batch loss 0.822052, batch nll 0.341076, batch error rate 20.000000%
# At minibatch 158700, batch loss 0.765481, batch nll 0.284358, batch error rate 8.000000%
# At minibatch 158800, batch loss 0.816684, batch nll 0.335533, batch error rate 12.000000%
# At minibatch 158900, batch loss 0.703720, batch nll 0.222436, batch error rate 8.000000%
# At minibatch 159000, batch loss 0.753167, batch nll 0.271719, batch error rate 8.000000%
# At minibatch 159100, batch loss 0.815327, batch nll 0.333887, batch error rate 8.000000%
# At minibatch 159200, batch loss 0.799180, batch nll 0.317792, batch error rate 4.000000%
# At minibatch 159300, batch loss 0.742393, batch nll 0.260838, batch error rate 4.000000%
# At minibatch 159400, batch loss 0.841941, batch nll 0.360236, batch error rate 16.000000%
# At minibatch 159500, batch loss 0.797196, batch nll 0.315566, batch error rate 12.000000%
# At minibatch 159600, batch loss 1.017539, batch nll 0.535904, batch error rate 20.000000%
# At minibatch 159700, batch loss 1.078794, batch nll 0.597192, batch error rate 24.000000%
# At minibatch 159800, batch loss 0.652621, batch nll 0.170953, batch error rate 4.000000%
# At minibatch 159900, batch loss 0.576317, batch nll 0.094886, batch error rate 0.000000%
# At minibatch 160000, batch loss 0.832020, batch nll 0.350547, batch error rate 20.000000%
# After epoch 100: valid_err_rate: 17.960000% currently going to do 146 epochs
# After epoch 100: averaged train_err_rate: 10.915000% averaged train nll: 0.330912 averaged train loss: 0.812282
# At minibatch 160100, batch loss 0.722632, batch nll 0.241116, batch error rate 16.000000%
# At minibatch 160200, batch loss 0.762127, batch nll 0.280603, batch error rate 12.000000%
# At minibatch 160300, batch loss 0.679251, batch nll 0.197594, batch error rate 4.000000%
# At minibatch 160400, batch loss 0.855509, batch nll 0.373880, batch error rate 12.000000%
# At minibatch 160500, batch loss 0.640314, batch nll 0.158649, batch error rate 4.000000%
# At minibatch 160600, batch loss 0.834846, batch nll 0.353044, batch error rate 4.000000%
# At minibatch 160700, batch loss 0.784889, batch nll 0.303022, batch error rate 12.000000%
# At minibatch 160800, batch loss 0.764310, batch nll 0.282399, batch error rate 8.000000%
# At minibatch 160900, batch loss 0.587628, batch nll 0.105775, batch error rate 4.000000%
# At minibatch 161000, batch loss 0.819670, batch nll 0.337737, batch error rate 12.000000%
# At minibatch 161100, batch loss 0.785863, batch nll 0.303954, batch error rate 8.000000%
# At minibatch 161200, batch loss 1.069009, batch nll 0.586974, batch error rate 16.000000%
# At minibatch 161300, batch loss 1.007119, batch nll 0.525165, batch error rate 16.000000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-7de39c63c6d7> in <module>()
#      12         momentum=0.9
#      13
# ---> 14         L, err_rate, nll, wdec = train_step(shake(X_batch), Y_batch, lrate, momentum)
#      15
#      16         train_loss.append((i,L))
#
# /pio/os/anaconda/lib/python2.7/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Test error rate is %f%%" %(compute_error_rate(cifar_test_stream)*100.0,)

figure(figsize(12,6))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
train_erros_av = zeros(train_erros_a.shape[0])
for i in range(train_erros_a.shape[0]):
    train_erros_av[i] = mean(train_erros_a[max(0,i-1000):i+1,1])
plot(train_erros_a[:,0], train_erros_av, label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate (smoothed)', color='r')
ylim(0,1.)
legend()
show()
# Out:
# Setting network parameters from after epoch 97
# Test error rate is 17.820000%

# %%
from common.plotting import plot_mat

# %%
#How do the filters in the first layer look like?

plot_mat(CW1.get_value(), cmap='gray')

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=4

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
