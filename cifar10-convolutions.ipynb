# %% [markdown]
# # CIFAR10 classification with convolutional neural network

# %% [markdown]
# Michał Łowicki, 258350

# %% [markdown]
# Code adapted from the [MNIST convolutions example](https://sites.google.com/a/cs.uni.wroc.pl/jch/teaching/neuralnetworks15/materialsforlectures710/10-convolutions.ipynb).

# %% [markdown]
# ###Test data accuracy: x%

# %% [markdown]
# ### Architecture
#
# This neural network consists of the following layers:
#
# 1. Convolution with 50 5x5 filters
# 2. 2x2 maxpool
# 3. Convolution with 100 5x5 filters
# 4. 2x2 maxpool
# 5. Fully connected with 500 neurons
# 6. ReLU
# 7. Fully connected with 500 neurons
# 8. ReLU
# 9. Fully connected with 100 neurons
# 10. ReLU
# 11. Fully connected with 10 neurons
# 12. SoftMax

# %%
# %pylab inline

import theano
import theano.tensor.signal.downsample
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 29 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 29 days
# Using gpu device 0: GeForce GTX 780
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Data streams

# %%
from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

CIFAR10.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}))

cifar_train = CIFAR10(("train",), subset=slice(None,40000))
#this stream will shuffle the CIFAR set and return us batches of 25 examples
cifar_train_stream = DataStream.default_stream(
    cifar_train,
    iteration_scheme=ShuffledScheme(cifar_train.num_examples, 25))
                                               
cifar_validation = CIFAR10(("train",), subset=slice(40000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar_validation_stream = DataStream.default_stream(
    cifar_validation, iteration_scheme=SequentialScheme(cifar_validation.num_examples, 100))
cifar_test = CIFAR10(("test",))
cifar_test_stream = DataStream.default_stream(
    cifar_test, iteration_scheme=SequentialScheme(cifar_test.num_examples, 100))

# %%
print "The streams return batches containing %s" % (cifar_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(cifar_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(cifar_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# A theano variable is an entry to the cmputational graph
# We will need to provide its value during function call
# X is batch_size x num_channels x img_rows x img_columns
X = theano.tensor.tensor4('X')

# Y is 1D, it lists the targets for all examples
Y = theano.tensor.matrix('Y', dtype='uint8')

#The tag values are useful during debugging the creation of Theano graphs

X_test_value, Y_test_value = next(cifar_train_stream.get_epoch_iterator())
#
# Unfortunately, test tags don't work with convolutions with newest Theano :(
#
theano.config.compute_test_value = 'raise' # Enable the computation of test values


X.tag.test_value = X_test_value[:3]
Y.tag.test_value = Y_test_value[:3]

print "X shape: %s" % (X.tag.test_value.shape,)

# this list will hold all parameters of the network
model_parameters = []

#The first convolutional layer
#The shape is: num_out_filters x num_in_filters x filter_height x filter_width
num_filters_1 = 50 #we will apply that many convolution filters in the first layer
CW1 = theano.shared(np.zeros((num_filters_1,3,5,5), dtype='float32'),
                   name='CW1')
#please note - this is somewhat non-standard
CW1.tag.initializer = IsotropicGaussian(0.05)

CB1 = theano.shared(np.zeros((num_filters_1,), dtype='float32'),
                    name='CB1')
CB1.tag.initializer = Constant(0.0)
model_parameters += [CW1, CB1]

after_C1 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(X, CW1) + CB1.dimshuffle('x',0,'x','x')
    )
# print "after_C1 shape: %s" % (after_C1.tag.test_value.shape,)
after_P1 = theano.tensor.signal.downsample.max_pool_2d(after_C1, (2,2), ignore_border=True)
# print "after_P1 shape: %s" % (after_P1.tag.test_value.shape,)


num_filters_2 = 100 #we will compute ten convolution filters in the first layer
CW2 = theano.shared(np.zeros((num_filters_2,num_filters_1,5,5), dtype='float32'),
                   name='CW2')
CW2.tag.initializer = IsotropicGaussian(0.05)

CB2 = theano.shared(np.zeros((num_filters_2,), dtype='float32'),
                    name='CB2')
CB2.tag.initializer = Constant(0.0)
model_parameters += [CW2, CB2]

after_C2 = theano.tensor.maximum(
    0.0,
    theano.tensor.nnet.conv2d(after_P1, CW2) + CB2.dimshuffle('x',0,'x','x')
    )
# print "after_C2 shape: %s" % (after_C2.tag.test_value.shape,)
after_P2 = theano.tensor.signal.downsample.max_pool_2d(after_C2, (2,2), ignore_border=True)
# print "after_P2 shape: %s" % (after_P2.tag.test_value.shape,)

#Fully connected layers - we just flatten all filter maps
num_fw3_hidden=500
FW3 = theano.shared(np.zeros((num_filters_2 * 5 * 5, num_fw3_hidden), dtype='float32'),
                   name='FW3')
FW3.tag.initializer = IsotropicGaussian(0.05)

FB3 = theano.shared(np.zeros((num_fw3_hidden,), dtype='float32'),
                    name='FB3')
FB3.tag.initializer = Constant(0.0)
model_parameters += [FW3, FB3]

after_F3 = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_P2.flatten(2), FW3) + FB3.dimshuffle('x',0))
# print "after_F3 shape: %s" % (after_F3.tag.test_value.shape,)

num_fw3a_hidden=500
FW3a = theano.shared(np.zeros((num_fw3_hidden, num_fw3a_hidden), dtype='float32'),
                   name='FW3a')
FW3a.tag.initializer = IsotropicGaussian(0.05)

FB3a = theano.shared(np.zeros((num_fw3a_hidden,), dtype='float32'),
                    name='FB3a')
FB3a.tag.initializer = Constant(0.0)
model_parameters += [FW3a, FB3a]

after_F3a = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3, FW3a) + FB3a.dimshuffle('x',0))
# print "after_F3a shape: %s" % (after_F3a.tag.test_value.shape,)

num_fw3b_hidden=100
FW3b = theano.shared(np.zeros((num_fw3a_hidden, num_fw3b_hidden), dtype='float32'),
                   name='FW3b')
FW3b.tag.initializer = IsotropicGaussian(0.05)

FB3b = theano.shared(np.zeros((num_fw3b_hidden,), dtype='float32'),
                    name='FB3b')
FB3b.tag.initializer = Constant(0.0)
model_parameters += [FW3b, FB3b]

after_F3b = theano.tensor.maximum(0.0, 
                                 theano.tensor.dot(after_F3a, FW3b) + FB3b.dimshuffle('x',0))
# print "after_F3b shape: %s" % (after_F3b.tag.test_value.shape,)

num_fw4_hidden=10
FW4 = theano.shared(np.zeros((num_fw3b_hidden, num_fw4_hidden), dtype='float32'),
                   name='FW4')
FW4.tag.initializer = IsotropicGaussian(0.05)

FB4 = theano.shared(np.zeros((num_fw4_hidden,), dtype='float32'),
                    name='FB4')
FB4.tag.initializer = Constant(0.0)
model_parameters += [FW4, FB4]

after_F4 = theano.tensor.dot(after_F3b, FW4) + FB4.dimshuffle('x',0)
# print "after_F4 shape: %s" % (after_F4.tag.test_value.shape,)

log_probs = theano.tensor.nnet.softmax(after_F4)

predictions = theano.tensor.argmax(log_probs, axis=1)

error_rate = theano.tensor.neq(predictions,Y.ravel()).mean()
nll = - theano.tensor.log(log_probs[theano.tensor.arange(Y.shape[0]), Y.ravel()]).mean()

weight_decay = 0.0
for p in model_parameters:
    if p.name[1]=='W':
        weight_decay = weight_decay + 2e-3 * (p**2).sum()

cost = nll + weight_decay

#At this point stop computing test values
theano.config.compute_test_value = 'off' # Enable the computation of test values
# Out:
# X shape: (3, 3, 32, 32)

# %%
#
# We have built a computation graph for computing the error_rate, predictions and cost
#
#svgdotprint(nll)

# %%
# The updates will update our shared values
updates = []

# %%
lrate = theano.tensor.scalar('lrate',dtype='float32')
momentum = theano.tensor.scalar('momentum',dtype='float32')

# Theano will compute the gradients for us
gradients = theano.grad(cost, model_parameters)

#initialize storage for momentum
velocities = [theano.shared(np.zeros_like(p.get_value()), name='V_%s' %(p.name, )) for p in model_parameters]

for p,g,v in zip(model_parameters, gradients, velocities):
    v_new = momentum * v - lrate * g
    p_new = p + v_new
    updates += [(v,v_new), (p, p_new)]

# %%
updates
# Out:
# [(V_CW1, Elemwise{sub,no_inplace}.0),
#  (CW1, Elemwise{add,no_inplace}.0),
#  (V_CB1, Elemwise{sub,no_inplace}.0),
#  (CB1, Elemwise{add,no_inplace}.0),
#  (V_CW2, Elemwise{sub,no_inplace}.0),
#  (CW2, Elemwise{add,no_inplace}.0),
#  (V_CB2, Elemwise{sub,no_inplace}.0),
#  (CB2, Elemwise{add,no_inplace}.0),
#  (V_FW3, Elemwise{sub,no_inplace}.0),
#  (FW3, Elemwise{add,no_inplace}.0),
#  (V_FB3, Elemwise{sub,no_inplace}.0),
#  (FB3, Elemwise{add,no_inplace}.0),
#  (V_FW3a, Elemwise{sub,no_inplace}.0),
#  (FW3a, Elemwise{add,no_inplace}.0),
#  (V_FB3a, Elemwise{sub,no_inplace}.0),
#  (FB3a, Elemwise{add,no_inplace}.0),
#  (V_FW3b, Elemwise{sub,no_inplace}.0),
#  (FW3b, Elemwise{add,no_inplace}.0),
#  (V_FB3b, Elemwise{sub,no_inplace}.0),
#  (FB3b, Elemwise{add,no_inplace}.0),
#  (V_FW4, Elemwise{sub,no_inplace}.0),
#  (FW4, Elemwise{add,no_inplace}.0),
#  (V_FB4, Elemwise{sub,no_inplace}.0),
#  (FB4, Elemwise{add,no_inplace}.0)]

# %%
#compile theano functions

#each call to train step will make one SGD step
train_step = theano.function([X,Y,lrate,momentum],[cost, error_rate, nll, weight_decay],updates=updates)
#each call to predict will return predictions on a batch of data
predict = theano.function([X], predictions)

# %%
def compute_error_rate(stream):
    errs = 0.0
    num_samples = 0.0
    for X, Y in stream.get_epoch_iterator():
        errs += (predict(X)!=Y.ravel()).sum()
        num_samples += Y.shape[0]
    return errs/num_samples

# %%
#utilities to save values of parameters and to load them

def init_parameters():
    rng = np.random.RandomState(1234)
    for p in model_parameters:
        p.set_value(p.tag.initializer.generate(rng, p.get_value().shape))

def snapshot_parameters():
    return [p.get_value(borrow=False) for p in model_parameters]

def load_parameters(snapshot):
    for p, s in zip(model_parameters, snapshot):
        p.set_value(s, borrow=False)

# %%
# init training

i=0
e=0

init_parameters()
for v in velocities:
    v.set_value(np.zeros_like(v.get_value()))

best_valid_error_rate = np.inf
best_params = snapshot_parameters()
best_params_epoch = 0

train_erros = []
train_loss = []
train_nll = []
validation_errors = []

number_of_epochs = 3
patience_expansion = 1.5

# %%
# training loop

while e<number_of_epochs: #This loop goes over epochs
    e += 1
    #First train on all data from this batch
    epoch_start_i = i
    for X_batch, Y_batch in cifar_train_stream.get_epoch_iterator(): 
        i += 1
        
        K = 2000
        lrate = 2e-2 * K / np.maximum(K, i)
        momentum=0.9
        
        L, err_rate, nll, wdec = train_step(X_batch, Y_batch, lrate, momentum)
        
        train_loss.append((i,L))
        train_erros.append((i,err_rate))
        train_nll.append((i,nll))
        if i % 100 == 0:
            print "At minibatch %d, batch loss %f, batch nll %f, batch error rate %f%%" % (i, L, nll, err_rate*100)
        
    # After an epoch compute validation error
    val_error_rate = compute_error_rate(cifar_validation_stream)
    if val_error_rate < best_valid_error_rate:
        number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
        best_valid_error_rate = val_error_rate
        best_params = snapshot_parameters()
        best_params_epoch = e
    validation_errors.append((i,val_error_rate))
    print "After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
        e, val_error_rate*100, number_of_epochs)
    print "After epoch %d: averaged train_err_rate: %f%% averaged train nll: %f averaged train loss: %f" %(
        e, np.mean(np.asarray(train_erros)[epoch_start_i:,1])*100, 
        np.mean(np.asarray(train_nll)[epoch_start_i:,1]),
        np.mean(np.asarray(train_loss)[epoch_start_i:,1]))
# Out:
# At minibatch 100, batch loss 9.135473, batch nll 1.841481, batch error rate 64.000000%
# At minibatch 200, batch loss 7.976509, batch nll 1.735036, batch error rate 60.000000%
# At minibatch 300, batch loss 7.465971, batch nll 2.120922, batch error rate 84.000000%
# At minibatch 400, batch loss 6.474575, batch nll 1.890185, batch error rate 60.000000%
# At minibatch 500, batch loss 5.516012, batch nll 1.578314, batch error rate 56.000000%
# At minibatch 600, batch loss 5.088835, batch nll 1.704305, batch error rate 60.000000%
# At minibatch 700, batch loss 4.453957, batch nll 1.534841, batch error rate 64.000000%
# At minibatch 800, batch loss 4.153383, batch nll 1.633716, batch error rate 60.000000%
# At minibatch 900, batch loss 3.655547, batch nll 1.471040, batch error rate 56.000000%
# At minibatch 1000, batch loss 3.344619, batch nll 1.447553, batch error rate 60.000000%
# At minibatch 1100, batch loss 2.881573, batch nll 1.227784, batch error rate 40.000000%
# At minibatch 1200, batch loss 2.682510, batch nll 1.236820, batch error rate 44.000000%
# At minibatch 1300, batch loss 2.713129, batch nll 1.442886, batch error rate 48.000000%
# At minibatch 1400, batch loss 2.542647, batch nll 1.417611, batch error rate 48.000000%
# At minibatch 1500, batch loss 2.314718, batch nll 1.308286, batch error rate 52.000000%
# At minibatch 1600, batch loss 2.322663, batch nll 1.426969, batch error rate 52.000000%
# After epoch 1: valid_err_rate: 52.180000% currently going to do 3 epochs
# After epoch 1: averaged train_err_rate: 58.860000% averaged train nll: 1.616324 averaged train loss: 4.827807
# At minibatch 1700, batch loss 1.856532, batch nll 1.040861, batch error rate 36.000000%
# At minibatch 1800, batch loss 2.247363, batch nll 1.501974, batch error rate 60.000000%
# At minibatch 1900, batch loss 1.597231, batch nll 0.910538, batch error rate 40.000000%
# At minibatch 2000, batch loss 2.459226, batch nll 1.828587, batch error rate 60.000000%
# At minibatch 2100, batch loss 2.223759, batch nll 1.636150, batch error rate 56.000000%
# At minibatch 2200, batch loss 1.826246, batch nll 1.274341, batch error rate 52.000000%
# At minibatch 2300, batch loss 1.838340, batch nll 1.316265, batch error rate 52.000000%
# At minibatch 2400, batch loss 1.763427, batch nll 1.264469, batch error rate 32.000000%
# At minibatch 2500, batch loss 1.570841, batch nll 1.093921, batch error rate 36.000000%
# At minibatch 2600, batch loss 1.436000, batch nll 0.974431, batch error rate 32.000000%
# At minibatch 2700, batch loss 1.990411, batch nll 1.544029, batch error rate 44.000000%
# At minibatch 2800, batch loss 1.762590, batch nll 1.329203, batch error rate 48.000000%
# At minibatch 2900, batch loss 1.153993, batch nll 0.730658, batch error rate 28.000000%
# At minibatch 3000, batch loss 1.391501, batch nll 0.976101, batch error rate 32.000000%
# At minibatch 3100, batch loss 1.481355, batch nll 1.073757, batch error rate 40.000000%
# At minibatch 3200, batch loss 1.834131, batch nll 1.431949, batch error rate 44.000000%
# After epoch 2: valid_err_rate: 40.290000% currently going to do 4 epochs
# After epoch 2: averaged train_err_rate: 45.897500% averaged train nll: 1.295207 averaged train loss: 1.841361
# At minibatch 3300, batch loss 1.724459, batch nll 1.324840, batch error rate 28.000000%
# At minibatch 3400, batch loss 1.747014, batch nll 1.354269, batch error rate 40.000000%
# At minibatch 3500, batch loss 1.234270, batch nll 0.841486, batch error rate 28.000000%
# At minibatch 3600, batch loss 1.655511, batch nll 1.265436, batch error rate 44.000000%
# At minibatch 3700, batch loss 1.272255, batch nll 0.884324, batch error rate 28.000000%
# At minibatch 3800, batch loss 1.529492, batch nll 1.144050, batch error rate 36.000000%
# At minibatch 3900, batch loss 1.463553, batch nll 1.080051, batch error rate 36.000000%
# At minibatch 4000, batch loss 1.685719, batch nll 1.303385, batch error rate 44.000000%
# At minibatch 4100, batch loss 1.200592, batch nll 0.819000, batch error rate 24.000000%
# At minibatch 4200, batch loss 1.196720, batch nll 0.817110, batch error rate 36.000000%
# At minibatch 4300, batch loss 2.065845, batch nll 1.687381, batch error rate 52.000000%
# At minibatch 4400, batch loss 1.374288, batch nll 0.997619, batch error rate 40.000000%
# At minibatch 4500, batch loss 1.378342, batch nll 1.005416, batch error rate 48.000000%
# At minibatch 4600, batch loss 1.325912, batch nll 0.955126, batch error rate 36.000000%
# At minibatch 4700, batch loss 1.684733, batch nll 1.314504, batch error rate 48.000000%
# At minibatch 4800, batch loss 1.273823, batch nll 0.906318, batch error rate 36.000000%
# After epoch 3: valid_err_rate: 32.870000% currently going to do 5 epochs
# After epoch 3: averaged train_err_rate: 36.872500% averaged train nll: 1.046805 averaged train loss: 1.429724
# At minibatch 4900, batch loss 1.440635, batch nll 1.069520, batch error rate 44.000000%
# At minibatch 5000, batch loss 0.950334, batch nll 0.576484, batch error rate 12.000000%
# At minibatch 5100, batch loss 1.163823, batch nll 0.788882, batch error rate 24.000000%
# At minibatch 5200, batch loss 1.627577, batch nll 1.253176, batch error rate 44.000000%
# At minibatch 5300, batch loss 1.100541, batch nll 0.726382, batch error rate 28.000000%
# At minibatch 5400, batch loss 1.044636, batch nll 0.671247, batch error rate 24.000000%
# At minibatch 5500, batch loss 1.043336, batch nll 0.669111, batch error rate 28.000000%
# At minibatch 5600, batch loss 1.281990, batch nll 0.906555, batch error rate 24.000000%
# At minibatch 5700, batch loss 1.247481, batch nll 0.870697, batch error rate 24.000000%
# At minibatch 5800, batch loss 1.465790, batch nll 1.087624, batch error rate 40.000000%
# At minibatch 5900, batch loss 1.293517, batch nll 0.916281, batch error rate 28.000000%
# At minibatch 6000, batch loss 1.348337, batch nll 0.970510, batch error rate 32.000000%
# At minibatch 6100, batch loss 1.139256, batch nll 0.762694, batch error rate 32.000000%
# At minibatch 6200, batch loss 1.169037, batch nll 0.795164, batch error rate 24.000000%
# At minibatch 6300, batch loss 1.296396, batch nll 0.921438, batch error rate 32.000000%
# At minibatch 6400, batch loss 1.733086, batch nll 1.360170, batch error rate 44.000000%
# After epoch 4: valid_err_rate: 32.800000% currently going to do 7 epochs
# After epoch 4: averaged train_err_rate: 31.065000% averaged train nll: 0.887324 averaged train loss: 1.262267
# At minibatch 6500, batch loss 1.200440, batch nll 0.822893, batch error rate 28.000000%
# At minibatch 6600, batch loss 0.830701, batch nll 0.450534, batch error rate 12.000000%
# At minibatch 6700, batch loss 1.078804, batch nll 0.696830, batch error rate 24.000000%
# At minibatch 6800, batch loss 1.199286, batch nll 0.816692, batch error rate 36.000000%
# At minibatch 6900, batch loss 1.338722, batch nll 0.953550, batch error rate 32.000000%
# At minibatch 7000, batch loss 1.265491, batch nll 0.880308, batch error rate 28.000000%
# At minibatch 7100, batch loss 1.329640, batch nll 0.943713, batch error rate 32.000000%
# At minibatch 7200, batch loss 0.982813, batch nll 0.595428, batch error rate 20.000000%
# At minibatch 7300, batch loss 1.320566, batch nll 0.932047, batch error rate 32.000000%
# At minibatch 7400, batch loss 1.450736, batch nll 1.062886, batch error rate 36.000000%
# At minibatch 7500, batch loss 0.943000, batch nll 0.555250, batch error rate 24.000000%
# At minibatch 7600, batch loss 1.109065, batch nll 0.721307, batch error rate 24.000000%
# At minibatch 7700, batch loss 1.387790, batch nll 1.000028, batch error rate 32.000000%
# At minibatch 7800, batch loss 1.276011, batch nll 0.888769, batch error rate 32.000000%
# At minibatch 7900, batch loss 1.045820, batch nll 0.657398, batch error rate 16.000000%
# At minibatch 8000, batch loss 0.968328, batch nll 0.581425, batch error rate 20.000000%
# After epoch 5: valid_err_rate: 30.750000% currently going to do 8 epochs
# After epoch 5: averaged train_err_rate: 26.932500% averaged train nll: 0.773141 averaged train loss: 1.158210
# At minibatch 8100, batch loss 0.880321, batch nll 0.490180, batch error rate 12.000000%
# At minibatch 8200, batch loss 1.144787, batch nll 0.752977, batch error rate 28.000000%
# At minibatch 8300, batch loss 0.883891, batch nll 0.489535, batch error rate 16.000000%
# At minibatch 8400, batch loss 1.092099, batch nll 0.698180, batch error rate 24.000000%
# At minibatch 8500, batch loss 1.080279, batch nll 0.684827, batch error rate 28.000000%
# At minibatch 8600, batch loss 1.129769, batch nll 0.732971, batch error rate 36.000000%
# At minibatch 8700, batch loss 1.194275, batch nll 0.796589, batch error rate 28.000000%
# At minibatch 8800, batch loss 1.063877, batch nll 0.664052, batch error rate 28.000000%
# At minibatch 8900, batch loss 1.206901, batch nll 0.806236, batch error rate 32.000000%
# At minibatch 9000, batch loss 1.198059, batch nll 0.796399, batch error rate 32.000000%
# At minibatch 9100, batch loss 1.593415, batch nll 1.190911, batch error rate 36.000000%
# At minibatch 9200, batch loss 1.623427, batch nll 1.221940, batch error rate 44.000000%
# At minibatch 9300, batch loss 0.721729, batch nll 0.319926, batch error rate 8.000000%
# At minibatch 9400, batch loss 1.404153, batch nll 1.001668, batch error rate 36.000000%
# At minibatch 9500, batch loss 0.810762, batch nll 0.407822, batch error rate 16.000000%
# At minibatch 9600, batch loss 1.033098, batch nll 0.630101, batch error rate 20.000000%
# After epoch 6: valid_err_rate: 27.960000% currently going to do 10 epochs
# After epoch 6: averaged train_err_rate: 23.410000% averaged train nll: 0.674604 averaged train loss: 1.072531
# At minibatch 9700, batch loss 0.967382, batch nll 0.561150, batch error rate 24.000000%
# At minibatch 9800, batch loss 0.910120, batch nll 0.499846, batch error rate 16.000000%
# At minibatch 9900, batch loss 0.904040, batch nll 0.492133, batch error rate 16.000000%
# At minibatch 10000, batch loss 0.934959, batch nll 0.520874, batch error rate 12.000000%
# At minibatch 10100, batch loss 0.911516, batch nll 0.496027, batch error rate 20.000000%
# At minibatch 10200, batch loss 1.082288, batch nll 0.666154, batch error rate 24.000000%
# At minibatch 10300, batch loss 0.843434, batch nll 0.426449, batch error rate 20.000000%
# At minibatch 10400, batch loss 1.135591, batch nll 0.717699, batch error rate 32.000000%
# At minibatch 10500, batch loss 0.767039, batch nll 0.347700, batch error rate 16.000000%
# At minibatch 10600, batch loss 0.919372, batch nll 0.499816, batch error rate 20.000000%
# At minibatch 10700, batch loss 1.178869, batch nll 0.759056, batch error rate 20.000000%
# At minibatch 10800, batch loss 0.732982, batch nll 0.314470, batch error rate 8.000000%
# At minibatch 10900, batch loss 0.923140, batch nll 0.504015, batch error rate 16.000000%
# At minibatch 11000, batch loss 1.147152, batch nll 0.727884, batch error rate 32.000000%
# At minibatch 11100, batch loss 1.333997, batch nll 0.914218, batch error rate 28.000000%
# At minibatch 11200, batch loss 1.496698, batch nll 1.076670, batch error rate 28.000000%
# After epoch 7: valid_err_rate: 26.150000% currently going to do 11 epochs
# After epoch 7: averaged train_err_rate: 20.405000% averaged train nll: 0.591131 averaged train loss: 1.007120
# At minibatch 11300, batch loss 0.769513, batch nll 0.346610, batch error rate 8.000000%
# At minibatch 11400, batch loss 0.635461, batch nll 0.209834, batch error rate 4.000000%
# At minibatch 11500, batch loss 0.939638, batch nll 0.511936, batch error rate 12.000000%
# At minibatch 11600, batch loss 0.731172, batch nll 0.301326, batch error rate 4.000000%
# At minibatch 11700, batch loss 0.829500, batch nll 0.398000, batch error rate 8.000000%
# At minibatch 11800, batch loss 0.948731, batch nll 0.515744, batch error rate 24.000000%
# At minibatch 11900, batch loss 1.004185, batch nll 0.569694, batch error rate 20.000000%
# At minibatch 12000, batch loss 1.431648, batch nll 0.994902, batch error rate 32.000000%
# At minibatch 12100, batch loss 1.173894, batch nll 0.736391, batch error rate 32.000000%
# At minibatch 12200, batch loss 0.928614, batch nll 0.491405, batch error rate 16.000000%
# At minibatch 12300, batch loss 1.153833, batch nll 0.715931, batch error rate 24.000000%
# At minibatch 12400, batch loss 1.087627, batch nll 0.648648, batch error rate 24.000000%
# At minibatch 12500, batch loss 1.031218, batch nll 0.592776, batch error rate 24.000000%
# At minibatch 12600, batch loss 1.235840, batch nll 0.797951, batch error rate 24.000000%
# At minibatch 12700, batch loss 0.965758, batch nll 0.526751, batch error rate 20.000000%
# At minibatch 12800, batch loss 0.869504, batch nll 0.429893, batch error rate 8.000000%
# After epoch 8: valid_err_rate: 27.120000% currently going to do 11 epochs
# After epoch 8: averaged train_err_rate: 18.027500% averaged train nll: 0.519534 averaged train loss: 0.953287
# At minibatch 12900, batch loss 0.826138, batch nll 0.383684, batch error rate 12.000000%
# At minibatch 13000, batch loss 0.779751, batch nll 0.334615, batch error rate 4.000000%
# At minibatch 13100, batch loss 0.903966, batch nll 0.457625, batch error rate 20.000000%
# At minibatch 13200, batch loss 0.947411, batch nll 0.500296, batch error rate 8.000000%
# At minibatch 13300, batch loss 0.731725, batch nll 0.283353, batch error rate 16.000000%
# At minibatch 13400, batch loss 0.792959, batch nll 0.343434, batch error rate 16.000000%
# At minibatch 13500, batch loss 0.913644, batch nll 0.462376, batch error rate 12.000000%
# At minibatch 13600, batch loss 0.858961, batch nll 0.406400, batch error rate 8.000000%
# At minibatch 13700, batch loss 0.778762, batch nll 0.325416, batch error rate 12.000000%
# At minibatch 13800, batch loss 0.974321, batch nll 0.520244, batch error rate 16.000000%
# At minibatch 13900, batch loss 1.089515, batch nll 0.634947, batch error rate 28.000000%
# At minibatch 14000, batch loss 0.789623, batch nll 0.335286, batch error rate 16.000000%
# At minibatch 14100, batch loss 0.894538, batch nll 0.439316, batch error rate 12.000000%
# At minibatch 14200, batch loss 0.892426, batch nll 0.436267, batch error rate 16.000000%
# At minibatch 14300, batch loss 0.948139, batch nll 0.490478, batch error rate 20.000000%
# At minibatch 14400, batch loss 0.778467, batch nll 0.320810, batch error rate 12.000000%
# After epoch 9: valid_err_rate: 26.000000% currently going to do 14 epochs
# After epoch 9: averaged train_err_rate: 15.382500% averaged train nll: 0.447160 averaged train loss: 0.898292
# At minibatch 14500, batch loss 0.995910, batch nll 0.536345, batch error rate 20.000000%
# At minibatch 14600, batch loss 0.934777, batch nll 0.473516, batch error rate 20.000000%
# At minibatch 14700, batch loss 0.797294, batch nll 0.334094, batch error rate 12.000000%
# At minibatch 14800, batch loss 0.710009, batch nll 0.245753, batch error rate 8.000000%
# At minibatch 14900, batch loss 0.897013, batch nll 0.431726, batch error rate 8.000000%
# At minibatch 15000, batch loss 1.014418, batch nll 0.547591, batch error rate 16.000000%
# At minibatch 15100, batch loss 0.737412, batch nll 0.269526, batch error rate 8.000000%
# At minibatch 15200, batch loss 0.992191, batch nll 0.523509, batch error rate 12.000000%
# At minibatch 15300, batch loss 0.707383, batch nll 0.237482, batch error rate 8.000000%
# At minibatch 15400, batch loss 0.890243, batch nll 0.419650, batch error rate 8.000000%
# At minibatch 15500, batch loss 0.632318, batch nll 0.161433, batch error rate 0.000000%
# At minibatch 15600, batch loss 1.054083, batch nll 0.581774, batch error rate 32.000000%
# At minibatch 15700, batch loss 0.751158, batch nll 0.278688, batch error rate 12.000000%
# At minibatch 15800, batch loss 0.883670, batch nll 0.410994, batch error rate 12.000000%
# At minibatch 15900, batch loss 0.835733, batch nll 0.363257, batch error rate 12.000000%
# At minibatch 16000, batch loss 0.688990, batch nll 0.216587, batch error rate 12.000000%
# After epoch 10: valid_err_rate: 25.370000% currently going to do 16 epochs
# After epoch 10: averaged train_err_rate: 13.227500% averaged train nll: 0.385352 averaged train loss: 0.853077
# At minibatch 16100, batch loss 0.625288, batch nll 0.150844, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.858234, batch nll 0.382404, batch error rate 16.000000%
# At minibatch 16300, batch loss 1.067557, batch nll 0.590144, batch error rate 20.000000%
# At minibatch 16400, batch loss 0.743080, batch nll 0.265081, batch error rate 12.000000%
# At minibatch 16500, batch loss 0.953439, batch nll 0.474350, batch error rate 12.000000%
# At minibatch 16600, batch loss 0.712936, batch nll 0.233270, batch error rate 12.000000%
# At minibatch 16700, batch loss 1.224143, batch nll 0.743795, batch error rate 24.000000%
# At minibatch 16800, batch loss 0.755471, batch nll 0.274129, batch error rate 4.000000%
# At minibatch 16900, batch loss 0.688979, batch nll 0.207119, batch error rate 4.000000%
# At minibatch 17000, batch loss 0.858742, batch nll 0.375742, batch error rate 20.000000%
# At minibatch 17100, batch loss 0.808214, batch nll 0.324285, batch error rate 16.000000%
# At minibatch 17200, batch loss 0.856760, batch nll 0.371495, batch error rate 16.000000%
# At minibatch 17300, batch loss 0.893496, batch nll 0.407248, batch error rate 16.000000%
# At minibatch 17400, batch loss 0.742072, batch nll 0.255715, batch error rate 4.000000%
# At minibatch 17500, batch loss 0.791003, batch nll 0.303346, batch error rate 12.000000%
# At minibatch 17600, batch loss 1.018590, batch nll 0.530574, batch error rate 12.000000%
# After epoch 11: valid_err_rate: 26.400000% currently going to do 16 epochs
# After epoch 11: averaged train_err_rate: 10.725000% averaged train nll: 0.324544 averaged train loss: 0.805823
# At minibatch 17700, batch loss 0.690078, batch nll 0.201056, batch error rate 4.000000%
# At minibatch 17800, batch loss 0.561067, batch nll 0.071315, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.717417, batch nll 0.226361, batch error rate 8.000000%
# At minibatch 18000, batch loss 0.807142, batch nll 0.315242, batch error rate 8.000000%
# At minibatch 18100, batch loss 0.623565, batch nll 0.131102, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.640724, batch nll 0.148047, batch error rate 4.000000%
# At minibatch 18300, batch loss 0.878306, batch nll 0.385505, batch error rate 16.000000%
# At minibatch 18400, batch loss 0.595123, batch nll 0.101313, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.667426, batch nll 0.173953, batch error rate 0.000000%
# At minibatch 18600, batch loss 0.823011, batch nll 0.329039, batch error rate 12.000000%
# At minibatch 18700, batch loss 0.810368, batch nll 0.315806, batch error rate 8.000000%
# At minibatch 18800, batch loss 0.674797, batch nll 0.179750, batch error rate 4.000000%
# At minibatch 18900, batch loss 0.832022, batch nll 0.336212, batch error rate 8.000000%
# At minibatch 19000, batch loss 0.875062, batch nll 0.378780, batch error rate 8.000000%
# At minibatch 19100, batch loss 0.558243, batch nll 0.061419, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.643030, batch nll 0.145655, batch error rate 4.000000%
# After epoch 12: valid_err_rate: 24.370000% currently going to do 19 epochs
# After epoch 12: averaged train_err_rate: 8.552500% averaged train nll: 0.266701 averaged train loss: 0.759960
# At minibatch 19300, batch loss 0.737485, batch nll 0.239472, batch error rate 12.000000%
# At minibatch 19400, batch loss 0.606381, batch nll 0.108374, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.644835, batch nll 0.146260, batch error rate 4.000000%
# At minibatch 19600, batch loss 0.612523, batch nll 0.113585, batch error rate 4.000000%
# At minibatch 19700, batch loss 0.683152, batch nll 0.183736, batch error rate 4.000000%
# At minibatch 19800, batch loss 0.727340, batch nll 0.226821, batch error rate 8.000000%
# At minibatch 19900, batch loss 0.875957, batch nll 0.374855, batch error rate 8.000000%
# At minibatch 20000, batch loss 0.690947, batch nll 0.189903, batch error rate 8.000000%
# At minibatch 20100, batch loss 0.740722, batch nll 0.239473, batch error rate 8.000000%
# At minibatch 20200, batch loss 0.733846, batch nll 0.232030, batch error rate 4.000000%
# At minibatch 20300, batch loss 0.693885, batch nll 0.191059, batch error rate 8.000000%
# At minibatch 20400, batch loss 0.932936, batch nll 0.429659, batch error rate 12.000000%
# At minibatch 20500, batch loss 0.609655, batch nll 0.105687, batch error rate 0.000000%
# At minibatch 20600, batch loss 0.781356, batch nll 0.276905, batch error rate 4.000000%
# At minibatch 20700, batch loss 0.844543, batch nll 0.340084, batch error rate 12.000000%
# At minibatch 20800, batch loss 0.621812, batch nll 0.117259, batch error rate 0.000000%
# After epoch 13: valid_err_rate: 24.340000% currently going to do 20 epochs
# After epoch 13: averaged train_err_rate: 7.270000% averaged train nll: 0.227441 averaged train loss: 0.728618
# At minibatch 20900, batch loss 0.849682, batch nll 0.344814, batch error rate 12.000000%
# At minibatch 21000, batch loss 0.605256, batch nll 0.100097, batch error rate 4.000000%
# At minibatch 21100, batch loss 0.644006, batch nll 0.139181, batch error rate 4.000000%
# At minibatch 21200, batch loss 0.595194, batch nll 0.090378, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.772478, batch nll 0.267921, batch error rate 4.000000%
# At minibatch 21400, batch loss 0.758831, batch nll 0.254784, batch error rate 12.000000%
# At minibatch 21500, batch loss 0.837135, batch nll 0.332863, batch error rate 8.000000%
# At minibatch 21600, batch loss 0.746548, batch nll 0.242438, batch error rate 8.000000%
# At minibatch 21700, batch loss 0.724373, batch nll 0.220122, batch error rate 12.000000%
# At minibatch 21800, batch loss 0.647253, batch nll 0.143259, batch error rate 8.000000%
# At minibatch 21900, batch loss 0.662429, batch nll 0.158287, batch error rate 4.000000%
# At minibatch 22000, batch loss 0.600317, batch nll 0.095607, batch error rate 0.000000%
# At minibatch 22100, batch loss 0.644733, batch nll 0.139314, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.607993, batch nll 0.102056, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.798993, batch nll 0.292658, batch error rate 8.000000%
# At minibatch 22400, batch loss 0.787746, batch nll 0.281571, batch error rate 12.000000%
# After epoch 14: valid_err_rate: 24.050000% currently going to do 22 epochs
# After epoch 14: averaged train_err_rate: 5.440000% averaged train nll: 0.182753 averaged train loss: 0.687581
# At minibatch 22500, batch loss 0.613060, batch nll 0.106602, batch error rate 4.000000%
# At minibatch 22600, batch loss 0.649502, batch nll 0.143219, batch error rate 8.000000%
# At minibatch 22700, batch loss 0.626756, batch nll 0.121025, batch error rate 4.000000%
# At minibatch 22800, batch loss 0.553943, batch nll 0.048781, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.775294, batch nll 0.270323, batch error rate 12.000000%
# At minibatch 23000, batch loss 0.610665, batch nll 0.105437, batch error rate 0.000000%
# At minibatch 23100, batch loss 0.675624, batch nll 0.170905, batch error rate 4.000000%
# At minibatch 23200, batch loss 0.679857, batch nll 0.175589, batch error rate 8.000000%
# At minibatch 23300, batch loss 0.737870, batch nll 0.233951, batch error rate 12.000000%
# At minibatch 23400, batch loss 0.623961, batch nll 0.120046, batch error rate 4.000000%
# At minibatch 23500, batch loss 0.720481, batch nll 0.216562, batch error rate 4.000000%
# At minibatch 23600, batch loss 0.549434, batch nll 0.045402, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.665653, batch nll 0.161028, batch error rate 4.000000%
# At minibatch 23800, batch loss 0.661977, batch nll 0.157044, batch error rate 4.000000%
# At minibatch 23900, batch loss 0.625118, batch nll 0.119815, batch error rate 8.000000%
# At minibatch 24000, batch loss 0.756904, batch nll 0.251805, batch error rate 8.000000%
# After epoch 15: valid_err_rate: 23.670000% currently going to do 23 epochs
# After epoch 15: averaged train_err_rate: 3.995000% averaged train nll: 0.149960 averaged train loss: 0.654926
# At minibatch 24100, batch loss 0.635751, batch nll 0.131408, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.544350, batch nll 0.041101, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.598949, batch nll 0.096725, batch error rate 4.000000%
# At minibatch 24400, batch loss 0.615045, batch nll 0.113631, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.659913, batch nll 0.159078, batch error rate 4.000000%
# At minibatch 24600, batch loss 0.576163, batch nll 0.075723, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.628986, batch nll 0.128582, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.589771, batch nll 0.089944, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.554935, batch nll 0.055442, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.580622, batch nll 0.080963, batch error rate 0.000000%
# At minibatch 25100, batch loss 0.645053, batch nll 0.145410, batch error rate 4.000000%
# At minibatch 25200, batch loss 0.662554, batch nll 0.162881, batch error rate 4.000000%
# At minibatch 25300, batch loss 0.713650, batch nll 0.213693, batch error rate 4.000000%
# At minibatch 25400, batch loss 0.604856, batch nll 0.104800, batch error rate 8.000000%
# At minibatch 25500, batch loss 0.582289, batch nll 0.082289, batch error rate 0.000000%
# At minibatch 25600, batch loss 0.640855, batch nll 0.140702, batch error rate 8.000000%
# After epoch 16: valid_err_rate: 24.680000% currently going to do 23 epochs
# After epoch 16: averaged train_err_rate: 3.012500% averaged train nll: 0.122268 averaged train loss: 0.623147
# At minibatch 25700, batch loss 0.638606, batch nll 0.139224, batch error rate 8.000000%
# At minibatch 25800, batch loss 0.571218, batch nll 0.072995, batch error rate 4.000000%
# At minibatch 25900, batch loss 0.552327, batch nll 0.055409, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.574804, batch nll 0.078683, batch error rate 0.000000%
# At minibatch 26100, batch loss 0.559535, batch nll 0.063940, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.567601, batch nll 0.072571, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.578656, batch nll 0.084436, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.639391, batch nll 0.145734, batch error rate 8.000000%
# At minibatch 26500, batch loss 0.654202, batch nll 0.161220, batch error rate 8.000000%
# At minibatch 26600, batch loss 0.579106, batch nll 0.086401, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.594716, batch nll 0.102448, batch error rate 8.000000%
# At minibatch 26800, batch loss 0.562358, batch nll 0.070182, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.577721, batch nll 0.085965, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.586254, batch nll 0.094403, batch error rate 4.000000%
# At minibatch 27100, batch loss 0.558169, batch nll 0.066018, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.684307, batch nll 0.191798, batch error rate 8.000000%
# After epoch 17: valid_err_rate: 23.750000% currently going to do 23 epochs
# After epoch 17: averaged train_err_rate: 2.245000% averaged train nll: 0.101608 averaged train loss: 0.596064
# At minibatch 27300, batch loss 0.599728, batch nll 0.107485, batch error rate 4.000000%
# At minibatch 27400, batch loss 0.547877, batch nll 0.056607, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.588940, batch nll 0.098796, batch error rate 4.000000%
# At minibatch 27600, batch loss 0.597537, batch nll 0.108347, batch error rate 4.000000%
# At minibatch 27700, batch loss 0.599561, batch nll 0.111219, batch error rate 4.000000%
# At minibatch 27800, batch loss 0.775982, batch nll 0.288173, batch error rate 4.000000%
# At minibatch 27900, batch loss 0.535043, batch nll 0.047677, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.550025, batch nll 0.063278, batch error rate 0.000000%
# At minibatch 28100, batch loss 0.552838, batch nll 0.066508, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.591984, batch nll 0.106166, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.586170, batch nll 0.101063, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.622609, batch nll 0.137682, batch error rate 4.000000%
# At minibatch 28500, batch loss 0.530235, batch nll 0.045391, batch error rate 0.000000%
# At minibatch 28600, batch loss 0.582996, batch nll 0.098177, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.565893, batch nll 0.080916, batch error rate 4.000000%
# At minibatch 28800, batch loss 0.601846, batch nll 0.116645, batch error rate 4.000000%
# After epoch 18: valid_err_rate: 24.120000% currently going to do 23 epochs
# After epoch 18: averaged train_err_rate: 1.847500% averaged train nll: 0.091164 averaged train loss: 0.578593
# At minibatch 28900, batch loss 0.590136, batch nll 0.105609, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.521793, batch nll 0.038337, batch error rate 0.000000%
# At minibatch 29100, batch loss 0.541397, batch nll 0.058992, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.522483, batch nll 0.041285, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.523141, batch nll 0.043114, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.564943, batch nll 0.085620, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.527221, batch nll 0.048531, batch error rate 0.000000%
# At minibatch 29600, batch loss 0.550055, batch nll 0.072053, batch error rate 4.000000%
# At minibatch 29700, batch loss 0.549693, batch nll 0.072628, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.533897, batch nll 0.057477, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.588612, batch nll 0.112362, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.552955, batch nll 0.076608, batch error rate 0.000000%
# At minibatch 30100, batch loss 0.579956, batch nll 0.103566, batch error rate 4.000000%
# At minibatch 30200, batch loss 0.634067, batch nll 0.157649, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.573441, batch nll 0.096768, batch error rate 4.000000%
# At minibatch 30400, batch loss 0.534269, batch nll 0.057687, batch error rate 0.000000%
# After epoch 19: valid_err_rate: 24.060000% currently going to do 23 epochs
# After epoch 19: averaged train_err_rate: 1.292500% averaged train nll: 0.078636 averaged train loss: 0.557642
# At minibatch 30500, batch loss 0.502968, batch nll 0.027301, batch error rate 0.000000%
# At minibatch 30600, batch loss 0.513504, batch nll 0.039004, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.520215, batch nll 0.046761, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.539618, batch nll 0.066998, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.502796, batch nll 0.030874, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.543244, batch nll 0.072248, batch error rate 0.000000%
# At minibatch 31100, batch loss 0.511505, batch nll 0.041006, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.518255, batch nll 0.048433, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.546407, batch nll 0.077008, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.581170, batch nll 0.112204, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.613425, batch nll 0.144570, batch error rate 4.000000%
# At minibatch 31600, batch loss 0.545005, batch nll 0.075964, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.529837, batch nll 0.061095, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.605423, batch nll 0.136935, batch error rate 8.000000%
# At minibatch 31900, batch loss 0.575797, batch nll 0.107443, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.561426, batch nll 0.093011, batch error rate 0.000000%
# After epoch 20: valid_err_rate: 24.110000% currently going to do 23 epochs
# After epoch 20: averaged train_err_rate: 0.932500% averaged train nll: 0.070033 averaged train loss: 0.540902
# At minibatch 32100, batch loss 0.517083, batch nll 0.049434, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.539852, batch nll 0.073287, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.508748, batch nll 0.043470, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.509546, batch nll 0.045446, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.496780, batch nll 0.033507, batch error rate 0.000000%
# At minibatch 32600, batch loss 0.538521, batch nll 0.075954, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.510098, batch nll 0.048033, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.520380, batch nll 0.058880, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.492447, batch nll 0.031674, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.511319, batch nll 0.051040, batch error rate 0.000000%
# At minibatch 33100, batch loss 0.503462, batch nll 0.043792, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.530880, batch nll 0.071526, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.507552, batch nll 0.048377, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.516004, batch nll 0.057028, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.529100, batch nll 0.069903, batch error rate 4.000000%
# At minibatch 33600, batch loss 0.524936, batch nll 0.065538, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 23.970000% currently going to do 23 epochs
# After epoch 21: averaged train_err_rate: 0.600000% averaged train nll: 0.061565 averaged train loss: 0.523699
# At minibatch 33700, batch loss 0.522175, batch nll 0.063299, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.501503, batch nll 0.043248, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.494786, batch nll 0.037238, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.509357, batch nll 0.052486, batch error rate 0.000000%
# At minibatch 34100, batch loss 0.493624, batch nll 0.037621, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.497664, batch nll 0.042360, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.562930, batch nll 0.108226, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.535015, batch nll 0.080721, batch error rate 4.000000%
# At minibatch 34500, batch loss 0.484148, batch nll 0.030145, batch error rate 0.000000%
# At minibatch 34600, batch loss 0.496655, batch nll 0.042993, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.500075, batch nll 0.046308, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.485888, batch nll 0.032352, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.562051, batch nll 0.108432, batch error rate 4.000000%
# At minibatch 35000, batch loss 0.521256, batch nll 0.067875, batch error rate 0.000000%
# At minibatch 35100, batch loss 0.533945, batch nll 0.080560, batch error rate 4.000000%
# At minibatch 35200, batch loss 0.557928, batch nll 0.104568, batch error rate 4.000000%
# After epoch 22: valid_err_rate: 24.540000% currently going to do 23 epochs
# After epoch 22: averaged train_err_rate: 0.647500% averaged train nll: 0.063237 averaged train loss: 0.518466
# At minibatch 35300, batch loss 0.489377, batch nll 0.036687, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.475904, batch nll 0.024219, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.500752, batch nll 0.049919, batch error rate 0.000000%
# At minibatch 35600, batch loss 0.489935, batch nll 0.040026, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.560126, batch nll 0.110922, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.512282, batch nll 0.063883, batch error rate 4.000000%
# At minibatch 35900, batch loss 0.480385, batch nll 0.032466, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.493141, batch nll 0.045759, batch error rate 0.000000%
# At minibatch 36100, batch loss 0.472591, batch nll 0.025597, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.489281, batch nll 0.042640, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.473587, batch nll 0.027086, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.478682, batch nll 0.032327, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.528176, batch nll 0.081463, batch error rate 0.000000%
# At minibatch 36600, batch loss 0.468687, batch nll 0.021778, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.508464, batch nll 0.061591, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.501093, batch nll 0.054118, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 24.470000% currently going to do 23 epochs
# After epoch 23: averaged train_err_rate: 0.547500% averaged train nll: 0.059320 averaged train loss: 0.507761
# At minibatch 36900, batch loss 0.493838, batch nll 0.047404, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.545458, batch nll 0.100067, batch error rate 0.000000%
# At minibatch 37100, batch loss 0.496098, batch nll 0.051473, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.471169, batch nll 0.027123, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.489154, batch nll 0.045805, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.476260, batch nll 0.033538, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.494228, batch nll 0.052064, batch error rate 0.000000%
# At minibatch 37600, batch loss 0.472456, batch nll 0.030797, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.474237, batch nll 0.032890, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.522003, batch nll 0.080861, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.487254, batch nll 0.046269, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.513675, batch nll 0.072888, batch error rate 0.000000%
# At minibatch 38100, batch loss 0.493147, batch nll 0.052616, batch error rate 4.000000%
# At minibatch 38200, batch loss 0.482618, batch nll 0.042288, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.591077, batch nll 0.150916, batch error rate 4.000000%
# At minibatch 38400, batch loss 0.488328, batch nll 0.047701, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 24.120000% currently going to do 23 epochs
# After epoch 24: averaged train_err_rate: 0.450000% averaged train nll: 0.055267 averaged train loss: 0.497741

# %%
print "Setting network parameters from after epoch %d" %(best_params_epoch)
load_parameters(best_params)

print "Test error rate is %f%%" %(compute_error_rate(cifar_test_stream)*100.0,)

figure(figsize(12,6))

subplot(2,1,1)
train_nll_a = np.array(train_nll)
semilogy(train_nll_a[:,0], train_nll_a[:,1], label='batch train nll')
legend()

subplot(2,1,2)
train_erros_a = np.array(train_erros)
train_erros_av = zeros(train_erros_a.shape[0])
for i in range(train_erros_a.shape[0]):
    train_erros_av[i] = mean(train_erros_a[max(0,i-1000):i+1,1])
plot(train_erros_a[:,0], train_erros_av, label='batch train error rate')
validation_errors_a = np.array(validation_errors)
plot(validation_errors_a[:,0], validation_errors_a[:,1], label='validation error rate (smoothed)', color='r')
ylim(0,1.)
legend()
show()
# Out:
# Setting network parameters from after epoch 15
# Test error rate is 24.570000%

# %%
from common.plotting import plot_mat

# %%
#How do the filters in the first layer look like?

plot_mat(CW1.get_value(), cmap='gray')

# %%
iii = predict.maker.inputs[0]
X = iii.variable

# %%
# build a function that shows how the network processes an image

middle_layers_computer = theano.function([X], [
        X,
        after_C1,
        after_P1,
        after_C2,
        after_P2
        ])

# %%
img_num=4

middle_layers = middle_layers_computer(X_test_value[img_num:img_num+1])

for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
